# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import SimpleRNN, LSTM
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
from matplotlib.dates import DateFormatter
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
import numpy as np
import pandas as pd
import datetime
import holidays
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import warnings

warnings.filterwarnings('ignore')

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

SYMBOL = "INFY.NS"
SEQUENCE_LENGTH = 60

TRAIN_START_DATE = "2020-06-01"
TRAIN_END_DATE = "2025-05-31"

TEST_START_DATE = "2025-06-01"
TEST_END_DATE = "2025-07-01"

# Get Indian trading holidays
def get_nse_holidays():
    in_holidays = holidays.India(years=range(2020, 2026))
    return set(in_holidays.keys())

TRADING_HOLIDAYS = get_nse_holidays()

def is_valid_date(date_str):
    try:
        date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()
        if not (datetime.date(2025, 6, 1) <= date <= datetime.date(2025, 7, 1)):
            print("Date must be between 2025-06-01 and 2025-07-01.")
            return False
        if date.weekday() >= 5:
            print("Weekends are not trading days.")
            return False
        if date in TRADING_HOLIDAYS:
            print("Entered date is a trading holiday.")
            return False
        return True
    except ValueError:
        print("Invalid date format. Use YYYY-MM-DD.")
        return False

def get_stock_data():
    print("Fetching data from Yahoo Finance...")
    full_df = yf.download(SYMBOL, start=TRAIN_START_DATE, end=TEST_END_DATE)
    full_df = full_df[['Close']]
    full_df.dropna(inplace=True)
    full_df.index = pd.to_datetime(full_df.index)

    train_df = full_df.loc[TRAIN_START_DATE:TRAIN_END_DATE]
    test_df = full_df.loc[TEST_START_DATE:TEST_END_DATE]
    return train_df, test_df, full_df

# Prompt until valid date is entered
def get_user_date():
    while True:
        date_input = input("Enter a date (YYYY-MM-DD): ")
        if is_valid_date(date_input):
            return datetime.datetime.strptime(date_input, "%Y-%m-%d").date()

# Build the LSTM model
def build_model(input_shape, learning_rate=0.001): # Added learning_rate parameter
    model = Sequential()
    model.add(LSTM(units=50, activation='tanh', input_shape=input_shape))
    model.add(Dense(1))
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# Reinforcement Learning Fine-Tuning
class RLAgent:
    """
    A simple RL Agent to fine-tune the RNN model.
    The "environment" is the time series data, and the "action" is the prediction.
    The reward is based on prediction accuracy.
    """
    def __init__(self, model, learning_rate=0.001):
        self.model = model
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

    @tf.function
    def train_step(self, state, target):
        """
        Performs a single training step to fine-tune the model weights.
        """
        with tf.GradientTape() as tape:
            prediction = self.model(state, training=True)
            # Use Mean Squared Error directly as the loss to minimize
            loss = tf.reduce_mean(tf.square(tf.cast(target, tf.float32) - prediction))

        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))
        return loss # Return the mean loss for the batch


def fine_tune_with_rl(model, X_train, y_train, epochs=5, learning_rate=0.001, batch_size=32):
    """
    Fine- tunes the pre-trained RNN model using a simple reinforcement learning loop with batched data.
    """
    print("\n--- Starting Reinforcement Learning Fine-Tuning (Batched) ---")
    agent = RLAgent(model, learning_rate=learning_rate)

    # Create a TensorFlow Dataset and batch it
    dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
    dataset = dataset.batch(batch_size)

    num_batches = tf.data.experimental.cardinality(dataset).numpy()

    for epoch in range(epochs):
        total_loss = 0
        batch_count = 0
        for batch_x, batch_y in dataset:
            # Ensure batch_x has the correct shape (batch_size, sequence_length, 1)
            batch_x_reshaped = tf.reshape(batch_x, (tf.shape(batch_x)[0], tf.shape(batch_x)[1], 1))
            loss = agent.train_step(batch_x_reshaped, batch_y)
            total_loss += loss.numpy() # Sum up the mean loss for each batch
            batch_count += 1

        # Calculate average loss per epoch
        average_epoch_loss = total_loss / num_batches if num_batches > 0 else 0
        print(f"RL Epoch {epoch + 1}/{epochs}, Average Loss per Batch: {average_epoch_loss:.6f}") # Print average loss

    print("--- RL Fine-Tuning Complete ---")
    return model


def create_test_sequences(train_df, test_df, scaler):
    combined = pd.concat([train_df, test_df])
    scaled = scaler.transform(combined[['Close']])
    X_test = []
    test_dates = test_df.index.date

    for i in range(len(train_df), len(combined)):
        if i - SEQUENCE_LENGTH < 0:
            continue
        seq = scaled[i - SEQUENCE_LENGTH:i]
        X_test.append(seq)

    X_test = np.array(X_test)
    return X_test, test_dates

def predict_price_on_test(model, full_df, scaler, user_date):
    all_dates = full_df.index.date
    try:
        idx = list(all_dates).index(user_date)
    except ValueError:
        print("User date not found in data.")
        return None, None, user_date

    if idx < SEQUENCE_LENGTH:
        print("Not enough data to predict for this date.")
        return None, None, user_date

    input_seq = scaler.transform(full_df[['Close']].values)[idx - SEQUENCE_LENGTH:idx]
    input_seq = np.reshape(input_seq, (1, SEQUENCE_LENGTH, 1))

    predicted_scaled = model.predict(input_seq, verbose=0)
    predicted_price = scaler.inverse_transform(predicted_scaled)[0][0]

    actual_price = float(full_df.iloc[idx]['Close']) if idx < len(full_df) else None
    return predicted_price, actual_price, full_df.index[idx].date()

# Plot the result
def plot_results(df, predicted_date, predicted_price, actual_price):
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['Close'], label='Historical Close Price',zorder=1)
    #plt.axvline(pd.to_datetime(predicted_date), color='red', linestyle='--', label='Predicted Date')
    plt.scatter(pd.to_datetime(predicted_date), predicted_price, color='orange', label='Predicted Price',zorder=2)
    if actual_price is not None:
        plt.scatter(pd.to_datetime(predicted_date), actual_price, color='green', label='Actual Price',zorder=3, s=100)
    plt.title("INFOSYS Stock Price with Prediction (yfinance)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

#Plotting error with no. of epochs
def plot_training_loss(history):
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title("Training and Validation Loss Over Epochs (LSTM)") # Changed title
    plt.xlabel("Epoch no.")
    plt.ylabel("Loss (MSE)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def main():
    print("=== INFOSYS LSTM Stock Price Predictor (Test Phase June–July 2025) ===") # Changed title
    user_date = get_user_date()

    # Step 1: Get stock data
    train_df, test_df, full_df = get_stock_data()

    # Step 2: Preprocess
    scaler = MinMaxScaler()
    scaled_train = scaler.fit_transform(train_df[['Close']])
    X, y = [], []
    for i in range(SEQUENCE_LENGTH, len(scaled_train)):
        X.append(scaled_train[i - SEQUENCE_LENGTH:i])
        y.append(scaled_train[i])
    X = np.array(X)
    y = np.array(y)

    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)
    #early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
    # Step 3: Build and train model
    model = build_model((X_train.shape[1], 1), learning_rate=0.0005) # Reduced Adam learning rate
    print("Training LSTM model...") # Changed print statement
    history = model.fit(X_train, y_train, epochs=10000, batch_size=64, validation_data=(X_val, y_val), verbose = 1) #callbacks = [early_stop], verbose=1)

    #print(f"\nBest weights restored from epoch: {early_stop.best_epoch + 1}")

    # Step 4: Plot training loss
    plot_training_loss(history)

    # Step 5: Fine-tune with Reinforcement Learning
    rl_tuned_model = fine_tune_with_rl(model, X_train, y_train, epochs=150, learning_rate=0.0001, batch_size=32)

    # Predict on training data to evaluate performance
    y_train_pred_scaled = rl_tuned_model.predict(X_train, verbose=0)
    y_train_pred = scaler.inverse_transform(y_train_pred_scaled)
    y_true_train = scaler.inverse_transform(y_train.reshape(-1, 1))

    # Calculate and print training metrics
    mae_train = mean_absolute_error(y_true_train, y_train_pred)
    mse_train = mean_squared_error(y_true_train, y_train_pred)
    rmse_train = np.sqrt(mse_train)
    r2_train = r2_score(y_true_train, y_train_pred)
    mape_train = mean_absolute_percentage_error(y_true_train, y_train_pred) * 100
    accuracy_train = 100 - mape_train
    mse_percent_train = (mse_train / np.mean(y_true_train)) * 100 if np.mean(y_true_train) != 0 else np.nan
    mae_percent_train = (mae_train / np.mean(y_true_train)) * 100 if np.mean(y_true_train) != 0 else np.nan
    print("\n Training Set Performance Metrics (LSTM):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_train:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_train:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_train:.2f}")
    print(f" R² Score                  : {r2_train:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_train:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_train:.2f}%")
    print(f" MSE Percentage of Average Price : {mse_percent_train:.2f}%")
    print(f" MAE Percentage of Average Price : {mae_percent_train:.2f}%")

    # Predict on validation set
    y_val_pred_scaled = rl_tuned_model.predict(X_val, verbose=0)
    y_val_pred = scaler.inverse_transform(y_val_pred_scaled)
    y_val_true = scaler.inverse_transform(y_val.reshape(-1, 1))

    # Calculate and print validation metrics
    mae_val = mean_absolute_error(y_val_true, y_val_pred)
    mse_val = mean_squared_error(y_val_true, y_val_pred)
    rmse_val = np.sqrt(mse_val)
    r2_val = r2_score(y_val_true, y_val_pred)
    mape_val = mean_absolute_percentage_error(y_val_true, y_val_pred) * 100
    accuracy_val = 100 - mape_val
    mse_percent_val = (mse_val / np.mean(y_val_true)) * 100 if np.mean(y_val_true) != 0 else np.nan
    mae_percent_val = (mae_val / np.mean(y_val_true)) * 100 if np.mean(y_val_true) != 0 else np.nan
    print("\n Validation Set Performance Metrics (LSTM):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_val:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_val:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_val:.2f}")
    print(f" R² Score                  : {r2_val:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_val:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_val:.2f}%")
    print(f" MSE Percentage of Average Price: {mse_percent_val:.2f}%")
    print(f" MAE Percentage of Average Price: {mae_percent_val:.2f}%")


    # Step 6: Predict for user-input test date
    predicted_price, actual_price, predicted_date = predict_price_on_test(rl_tuned_model, full_df, scaler, user_date)
    if predicted_price is not None:
        print(f"\n Prediction for {predicted_date}:")
        print(f" Predicted Closing Price: ₹{predicted_price:.2f}")
        if actual_price is not None:
            print(f" Actual Closing Price   : ₹{actual_price}")
        else:
            print("Actual price not available.")

        plot_results(full_df, predicted_date, predicted_price, actual_price)
    else:
        print("❌ Unable to make prediction.")

    # === Step 7: Predict all test dates and compare ===

    # Reuse combined full_df
    combined_df = pd.concat([train_df, test_df])
    scaled_combined = scaler.transform(combined_df[['Close']])

    X_test_all = []
    test_date_indexes = []

    for i in range(len(train_df), len(combined_df)):
        if i - SEQUENCE_LENGTH < 0:
            continue
        seq = scaled_combined[i - SEQUENCE_LENGTH:i]
        X_test_all.append(seq)
        test_date_indexes.append(combined_df.index[i])

    X_test_all = np.array(X_test_all)

    # Predict on test sequences
    y_test_pred_scaled = rl_tuned_model.predict(X_test_all, verbose=0)
    y_test_pred = scaler.inverse_transform(y_test_pred_scaled)

    # Actual prices
    y_test_true = test_df.loc[test_date_indexes, 'Close'].values

    # Calculate and print test metrics
    mae_test = mean_absolute_error(y_test_true, y_test_pred)
    mse_test = mean_squared_error(y_test_true, y_test_pred)
    rmse_test = np.sqrt(mse_test)
    r2_test = r2_score(y_test_true, y_test_pred)
    mape_test = mean_absolute_percentage_error(y_test_true, y_test_pred) * 100
    accuracy_test = 100 - mape_test
    mse_percent_test = (mse_test / np.mean(y_test_true)) * 100 if np.mean(y_test_true) != 0 else np.nan
    mae_percent_test = (mae_test / np.mean(y_test_true)) * 100 if np.mean(y_test_true) != 0 else np.nan
    print("\n Test Set Performance Metrics (LSTM):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_test:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_test:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_test:.2f}")
    print(f" R² Score                  : {r2_test:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_test:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_test:.2f}%")
    print(f" MSE Percentage of Average Price: {mse_percent_test:.2f}%")
    print(f" MAE Percentage of Average Price: {mae_percent_test:.2f}%")

    # Plot actual vs predicted
    plt.figure(figsize=(12, 6))
    plt.plot(test_date_indexes, y_test_true, label='Actual Price')
    plt.plot(test_date_indexes, y_test_pred, label='Predicted Price')
    plt.title("Actual vs Predicted INFY Closing Prices (01-Jun to 01-Jul 2025) (LSTM)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.xticks(rotation=45)
    plt.gca().xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# === INFOSYS LSTM Stock Price Predictor (Test Phase June–July 2025) ===
# Fetching data from Yahoo Finance...
# [*********************100%***********************]  1 of 1 completed
# Streaming output truncated to the last 5000 lines.
# Epoch 7501/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.5751e-05 - val_loss: 0.0358
# Epoch 7502/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.7912e-05 - val_loss: 0.0354
# Epoch 7503/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.3172e-05 - val_loss: 0.0353
# Epoch 7504/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.0790e-05 - val_loss: 0.0358
# Epoch 7505/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.7327e-05 - val_loss: 0.0361
# Epoch 7506/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.0265e-05 - val_loss: 0.0358
# Epoch 7507/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.8338e-05 - val_loss: 0.0365
# Epoch 7508/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.2232e-05 - val_loss: 0.0373
# Epoch 7509/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.5373e-05 - val_loss: 0.0384
# Epoch 7510/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.6002e-05 - val_loss: 0.0394
# Epoch 7511/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.3478e-05 - val_loss: 0.0399
# Epoch 7512/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.3649e-05 - val_loss: 0.0399
# Epoch 7513/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.4082e-05 - val_loss: 0.0399
# Epoch 7514/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.3954e-05 - val_loss: 0.0394
# Epoch 7515/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.6866e-05 - val_loss: 0.0388
# Epoch 7516/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.6326e-05 - val_loss: 0.0391
# Epoch 7517/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.7153e-05 - val_loss: 0.0392
# Epoch 7518/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.3867e-05 - val_loss: 0.0397
# Epoch 7519/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.1950e-05 - val_loss: 0.0388
# Epoch 7520/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.2490e-05 - val_loss: 0.0382
# Epoch 7521/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.2372e-05 - val_loss: 0.0372
# Epoch 7522/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.1189e-05 - val_loss: 0.0367
# Epoch 7523/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.3030e-05 - val_loss: 0.0368
# Epoch 7524/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.2187e-05 - val_loss: 0.0371
# Epoch 7525/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.1157e-05 - val_loss: 0.0377
# Epoch 7526/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.4624e-05 - val_loss: 0.0385
# Epoch 7527/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.6349e-05 - val_loss: 0.0398
# Epoch 7528/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.4029e-05 - val_loss: 0.0397
# Epoch 7529/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.3895e-05 - val_loss: 0.0398
# Epoch 7530/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.5763e-05 - val_loss: 0.0395
# Epoch 7531/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.1125e-05 - val_loss: 0.0398
# Epoch 7532/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.1217e-05 - val_loss: 0.0397
# Epoch 7533/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.0233e-05 - val_loss: 0.0389
# Epoch 7534/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.1950e-05 - val_loss: 0.0389
# Epoch 7535/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.1634e-05 - val_loss: 0.0386
# Epoch 7536/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.2868e-05 - val_loss: 0.0386
# Epoch 7537/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.3617e-05 - val_loss: 0.0384
# Epoch 7538/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.2206e-05 - val_loss: 0.0390
# Epoch 7539/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.8498e-05 - val_loss: 0.0394
# Epoch 7540/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.7785e-05 - val_loss: 0.0393
# Epoch 7541/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.6008e-05 - val_loss: 0.0391
# Epoch 7542/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.0605e-05 - val_loss: 0.0390
# Epoch 7543/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.9599e-05 - val_loss: 0.0392
# Epoch 7544/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.7436e-05 - val_loss: 0.0388
# Epoch 7545/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.2962e-05 - val_loss: 0.0395
# Epoch 7546/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2513e-05 - val_loss: 0.0397
# Epoch 7547/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.2944e-05 - val_loss: 0.0400
# Epoch 7548/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.2837e-05 - val_loss: 0.0396
# Epoch 7549/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.3902e-05 - val_loss: 0.0397
# Epoch 7550/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2407e-05 - val_loss: 0.0403
# Epoch 7551/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.3754e-05 - val_loss: 0.0400
# Epoch 7552/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1440e-05 - val_loss: 0.0402
# Epoch 7553/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.2432e-05 - val_loss: 0.0401
# Epoch 7554/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.2331e-05 - val_loss: 0.0402
# Epoch 7555/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2512e-05 - val_loss: 0.0400
# Epoch 7556/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.3751e-05 - val_loss: 0.0402
# Epoch 7557/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.3011e-05 - val_loss: 0.0405
# Epoch 7558/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.3106e-05 - val_loss: 0.0402
# Epoch 7559/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.3233e-05 - val_loss: 0.0404
# Epoch 7560/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.4659e-05 - val_loss: 0.0405
# Epoch 7561/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.5739e-05 - val_loss: 0.0409
# Epoch 7562/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.6692e-05 - val_loss: 0.0407
# Epoch 7563/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.7435e-05 - val_loss: 0.0408
# Epoch 7564/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.6025e-05 - val_loss: 0.0412
# Epoch 7565/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.7003e-05 - val_loss: 0.0411
# Epoch 7566/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.1076e-05 - val_loss: 0.0406
# Epoch 7567/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.0181e-05 - val_loss: 0.0393
# Epoch 7568/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.6367e-05 - val_loss: 0.0386
# Epoch 7569/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.5741e-05 - val_loss: 0.0391
# Epoch 7570/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.0639e-05 - val_loss: 0.0398
# Epoch 7571/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.5499e-05 - val_loss: 0.0410
# Epoch 7572/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.9157e-05 - val_loss: 0.0413
# Epoch 7573/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.6462e-05 - val_loss: 0.0403
# Epoch 7574/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.2231e-05 - val_loss: 0.0391
# Epoch 7575/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.0532e-05 - val_loss: 0.0371
# Epoch 7576/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.1990e-05 - val_loss: 0.0379
# Epoch 7577/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.3698e-05 - val_loss: 0.0387
# Epoch 7578/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.7414e-05 - val_loss: 0.0373
# Epoch 7579/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.6058e-05 - val_loss: 0.0379
# Epoch 7580/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.5013e-05 - val_loss: 0.0389
# Epoch 7581/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.8243e-05 - val_loss: 0.0395
# Epoch 7582/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.6249e-05 - val_loss: 0.0409
# Epoch 7583/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.0127e-05 - val_loss: 0.0397
# Epoch 7584/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.3182e-05 - val_loss: 0.0396
# Epoch 7585/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.6807e-05 - val_loss: 0.0401
# Epoch 7586/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7670e-05 - val_loss: 0.0397
# Epoch 7587/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.5216e-05 - val_loss: 0.0406
# Epoch 7588/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4552e-05 - val_loss: 0.0410
# Epoch 7589/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.6086e-05 - val_loss: 0.0413
# Epoch 7590/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.6831e-05 - val_loss: 0.0409
# Epoch 7591/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.1633e-05 - val_loss: 0.0409
# Epoch 7592/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.0419e-05 - val_loss: 0.0408
# Epoch 7593/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.9975e-05 - val_loss: 0.0410
# Epoch 7594/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.7072e-05 - val_loss: 0.0417
# Epoch 7595/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.6300e-05 - val_loss: 0.0416
# Epoch 7596/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.4484e-05 - val_loss: 0.0409
# Epoch 7597/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.5204e-05 - val_loss: 0.0404
# Epoch 7598/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.5029e-05 - val_loss: 0.0406
# Epoch 7599/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.6768e-05 - val_loss: 0.0399
# Epoch 7600/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.7098e-05 - val_loss: 0.0395
# Epoch 7601/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.6600e-05 - val_loss: 0.0393
# Epoch 7602/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.6134e-05 - val_loss: 0.0396
# Epoch 7603/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.7586e-05 - val_loss: 0.0405
# Epoch 7604/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.0127e-05 - val_loss: 0.0415
# Epoch 7605/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.2340e-05 - val_loss: 0.0420
# Epoch 7606/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.8104e-05 - val_loss: 0.0420
# Epoch 7607/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.6424e-05 - val_loss: 0.0419
# Epoch 7608/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.8187e-05 - val_loss: 0.0417
# Epoch 7609/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.4438e-05 - val_loss: 0.0426
# Epoch 7610/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.5349e-05 - val_loss: 0.0422
# Epoch 7611/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.0150e-05 - val_loss: 0.0416
# Epoch 7612/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.8538e-05 - val_loss: 0.0410
# Epoch 7613/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.4291e-05 - val_loss: 0.0392
# Epoch 7614/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.3261e-05 - val_loss: 0.0395
# Epoch 7615/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.2931e-05 - val_loss: 0.0397
# Epoch 7616/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.6083e-05 - val_loss: 0.0397
# Epoch 7617/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.6364e-05 - val_loss: 0.0404
# Epoch 7618/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.2225e-05 - val_loss: 0.0403
# Epoch 7619/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.2010e-05 - val_loss: 0.0408
# Epoch 7620/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.3883e-05 - val_loss: 0.0422
# Epoch 7621/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.9978e-05 - val_loss: 0.0426
# Epoch 7622/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.4452e-05 - val_loss: 0.0427
# Epoch 7623/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.1739e-05 - val_loss: 0.0409
# Epoch 7624/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.4879e-05 - val_loss: 0.0392
# Epoch 7625/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.6337e-05 - val_loss: 0.0386
# Epoch 7626/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.0535e-05 - val_loss: 0.0396
# Epoch 7627/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8251e-05 - val_loss: 0.0409
# Epoch 7628/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.1007e-05 - val_loss: 0.0418
# Epoch 7629/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.2655e-05 - val_loss: 0.0412
# Epoch 7630/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.9813e-05 - val_loss: 0.0422
# Epoch 7631/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.2796e-05 - val_loss: 0.0418
# Epoch 7632/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.0125e-05 - val_loss: 0.0418
# Epoch 7633/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.0815e-05 - val_loss: 0.0417
# Epoch 7634/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.1779e-05 - val_loss: 0.0406
# Epoch 7635/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.1061e-05 - val_loss: 0.0416
# Epoch 7636/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.3609e-05 - val_loss: 0.0419
# Epoch 7637/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.3058e-05 - val_loss: 0.0417
# Epoch 7638/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.8020e-05 - val_loss: 0.0421
# Epoch 7639/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.9303e-05 - val_loss: 0.0422
# Epoch 7640/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.5658e-05 - val_loss: 0.0407
# Epoch 7641/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.9271e-05 - val_loss: 0.0393
# Epoch 7642/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.8392e-05 - val_loss: 0.0387
# Epoch 7643/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.2301e-05 - val_loss: 0.0376
# Epoch 7644/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.7538e-05 - val_loss: 0.0367
# Epoch 7645/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.0609e-05 - val_loss: 0.0372
# Epoch 7646/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.2627e-05 - val_loss: 0.0379
# Epoch 7647/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.4834e-05 - val_loss: 0.0369
# Epoch 7648/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.3315e-05 - val_loss: 0.0380
# Epoch 7649/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.4496e-05 - val_loss: 0.0381
# Epoch 7650/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.3423e-05 - val_loss: 0.0385
# Epoch 7651/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.5053e-05 - val_loss: 0.0394
# Epoch 7652/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.7019e-05 - val_loss: 0.0406
# Epoch 7653/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.4956e-05 - val_loss: 0.0400
# Epoch 7654/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.5680e-05 - val_loss: 0.0398
# Epoch 7655/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.3996e-05 - val_loss: 0.0391
# Epoch 7656/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.9947e-05 - val_loss: 0.0406
# Epoch 7657/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.0275e-05 - val_loss: 0.0393
# Epoch 7658/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.3097e-05 - val_loss: 0.0390
# Epoch 7659/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.3479e-05 - val_loss: 0.0392
# Epoch 7660/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.2280e-05 - val_loss: 0.0393
# Epoch 7661/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.2287e-05 - val_loss: 0.0388
# Epoch 7662/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.0601e-05 - val_loss: 0.0379
# Epoch 7663/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.4074e-05 - val_loss: 0.0376
# Epoch 7664/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.0252e-05 - val_loss: 0.0369
# Epoch 7665/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.4073e-05 - val_loss: 0.0367
# Epoch 7666/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.3342e-05 - val_loss: 0.0371
# Epoch 7667/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.1290e-05 - val_loss: 0.0391
# Epoch 7668/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.3244e-05 - val_loss: 0.0402
# Epoch 7669/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.7259e-05 - val_loss: 0.0392
# Epoch 7670/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.7259e-05 - val_loss: 0.0386
# Epoch 7671/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.2576e-05 - val_loss: 0.0393
# Epoch 7672/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.1031e-05 - val_loss: 0.0405
# Epoch 7673/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.9078e-05 - val_loss: 0.0408
# Epoch 7674/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.9099e-05 - val_loss: 0.0403
# Epoch 7675/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.2160e-05 - val_loss: 0.0402
# Epoch 7676/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.3535e-05 - val_loss: 0.0405
# Epoch 7677/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.3181e-05 - val_loss: 0.0409
# Epoch 7678/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.4789e-05 - val_loss: 0.0411
# Epoch 7679/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.5420e-05 - val_loss: 0.0413
# Epoch 7680/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.7401e-05 - val_loss: 0.0418
# Epoch 7681/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.8323e-05 - val_loss: 0.0420
# Epoch 7682/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.3636e-05 - val_loss: 0.0420
# Epoch 7683/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.8757e-05 - val_loss: 0.0417
# Epoch 7684/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.0335e-05 - val_loss: 0.0420
# Epoch 7685/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.3062e-05 - val_loss: 0.0395
# Epoch 7686/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.7527e-05 - val_loss: 0.0400
# Epoch 7687/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.7195e-05 - val_loss: 0.0397
# Epoch 7688/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.4766e-05 - val_loss: 0.0391
# Epoch 7689/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.4449e-05 - val_loss: 0.0371
# Epoch 7690/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.3352e-05 - val_loss: 0.0371
# Epoch 7691/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.6511e-05 - val_loss: 0.0389
# Epoch 7692/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.8311e-05 - val_loss: 0.0402
# Epoch 7693/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.7530e-05 - val_loss: 0.0398
# Epoch 7694/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.4422e-05 - val_loss: 0.0407
# Epoch 7695/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.7029e-05 - val_loss: 0.0398
# Epoch 7696/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.1239e-04 - val_loss: 0.0404
# Epoch 7697/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1264e-04 - val_loss: 0.0401
# Epoch 7698/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3266e-04 - val_loss: 0.0397
# Epoch 7699/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3414e-04 - val_loss: 0.0395
# Epoch 7700/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2827e-04 - val_loss: 0.0376
# Epoch 7701/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2412e-04 - val_loss: 0.0371
# Epoch 7702/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0214e-04 - val_loss: 0.0371
# Epoch 7703/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.6071e-05 - val_loss: 0.0372
# Epoch 7704/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.2196e-05 - val_loss: 0.0372
# Epoch 7705/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.7495e-05 - val_loss: 0.0364
# Epoch 7706/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.
10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6506e-05 - val_loss: 0.0381
# Epoch 7760/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6303e-05 - val_loss: 0.0386
# Epoch 7761/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6284e-05 - val_loss: 0.0391
# Epoch 7762/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6599e-05 - val_loss: 0.0394
# Epoch 7763/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6745e-05 - val_loss: 0.0393
# Epoch 7764/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6552e-05 - val_loss: 0.0392
# Epoch 7765/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6081e-05 - val_loss: 0.0393
# Epoch 7766/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5857e-05 - val_loss: 0.0394
# Epoch 7767/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6090e-05 - val_loss: 0.0394
# Epoch 7768/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6413e-05 - val_loss: 0.0394
# Epoch 7769/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6341e-05 - val_loss: 0.0392
# Epoch 7770/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6041e-05 - val_loss: 0.0390
# Epoch 7771/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5694e-05 - val_loss: 0.0389
# Epoch 7772/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5867e-05 - val_loss: 0.0390
# Epoch 7773/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6344e-05 - val_loss: 0.0390
# Epoch 7774/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6728e-05 - val_loss: 0.0390
# Epoch 7775/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.8106e-05 - val_loss: 0.0391
# Epoch 7776/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.9215e-05 - val_loss: 0.0394
# Epoch 7777/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.8934e-05 - val_loss: 0.0405
# Epoch 7778/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.3832e-05 - val_loss: 0.0382
# Epoch 7779/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.7164e-05 - val_loss: 0.0385
# Epoch 7780/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.4651e-05 - val_loss: 0.0395
# Epoch 7781/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.2305e-05 - val_loss: 0.0377
# Epoch 7782/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.1317e-05 - val_loss: 0.0388
# Epoch 7783/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.4873e-05 - val_loss: 0.0387
# Epoch 7784/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.7000e-05 - val_loss: 0.0385
# Epoch 7785/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.0261e-05 - val_loss: 0.0388
# Epoch 7786/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.9815e-05 - val_loss: 0.0393
# Epoch 7787/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.3992e-05 - val_loss: 0.0380
# Epoch 7788/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.0005e-05 - val_loss: 0.0393
# Epoch 7789/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.8188e-05 - val_loss: 0.0414
# Epoch 7790/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.6269e-05 - val_loss: 0.0415
# Epoch 7791/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.3292e-05 - val_loss: 0.0404
# Epoch 7792/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.3796e-05 - val_loss: 0.0396
# Epoch 7793/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.1757e-05 - val_loss: 0.0401
# Epoch 7794/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1717e-05 - val_loss: 0.0398
# Epoch 7795/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.9553e-05 - val_loss: 0.0399
# Epoch 7796/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.0080e-05 - val_loss: 0.0402
# Epoch 7797/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.1913e-05 - val_loss: 0.0404
# Epoch 7798/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.3722e-05 - val_loss: 0.0406
# Epoch 7799/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.8173e-05 - val_loss: 0.0405
# Epoch 7800/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.1311e-05 - val_loss: 0.0406
# Epoch 7801/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.4638e-05 - val_loss: 0.0413
# Epoch 7802/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.6526e-05 - val_loss: 0.0414
# Epoch 7803/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.9530e-05 - val_loss: 0.0413
# Epoch 7804/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.4804e-05 - val_loss: 0.0410
# Epoch 7805/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.9878e-05 - val_loss: 0.0405
# Epoch 7806/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.2763e-05 - val_loss: 0.0398
# Epoch 7807/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.0306e-05 - val_loss: 0.0385
# Epoch 7808/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.9960e-05 - val_loss: 0.0395
# Epoch 7809/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.3597e-05 - val_loss: 0.0398
# Epoch 7810/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.9421e-05 - val_loss: 0.0401
# Epoch 7811/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.5707e-05 - val_loss: 0.0410
# Epoch 7812/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.6065e-05 - val_loss: 0.0412
# Epoch 7813/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.5525e-05 - val_loss: 0.0423
# Epoch 7814/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.0706e-05 - val_loss: 0.0430
# Epoch 7815/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.4961e-05 - val_loss: 0.0417
# Epoch 7816/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.5664e-05 - val_loss: 0.0425
# Epoch 7817/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.5697e-05 - val_loss: 0.0409
# Epoch 7818/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.6890e-05 - val_loss: 0.0424
# Epoch 7819/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.6499e-05 - val_loss: 0.0428
# Epoch 7820/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.4403e-05 - val_loss: 0.0404
# Epoch 7821/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.7802e-05 - val_loss: 0.0404
# Epoch 7822/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.7795e-05 - val_loss: 0.0402
# Epoch 7823/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.2461e-05 - val_loss: 0.0419
# Epoch 7824/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.7109e-05 - val_loss: 0.0404
# Epoch 7825/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.2528e-05 - val_loss: 0.0387
# Epoch 7826/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.6989e-05 - val_loss: 0.0381
# Epoch 7827/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.8537e-05 - val_loss: 0.0393
# Epoch 7828/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.7544e-05 - val_loss: 0.0397
# Epoch 7829/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.5568e-05 - val_loss: 0.0400
# Epoch 7830/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.6193e-05 - val_loss: 0.0400
# Epoch 7831/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.3581e-05 - val_loss: 0.0411
# Epoch 7832/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.5470e-05 - val_loss: 0.0414
# Epoch 7833/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.9816e-05 - val_loss: 0.0415
# Epoch 7834/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.1216e-05 - val_loss: 0.0420
# Epoch 7835/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.0732e-05 - val_loss: 0.0419
# Epoch 7836/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.0873e-05 - val_loss: 0.0408
# Epoch 7837/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7783e-05 - val_loss: 0.0410
# Epoch 7838/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.8924e-05 - val_loss: 0.0406
# Epoch 7839/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.0096e-05 - val_loss: 0.0406
# Epoch 7840/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.7530e-05 - val_loss: 0.0404
# Epoch 7841/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.5975e-05 - val_loss: 0.0405
# Epoch 7842/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.5012e-05 - val_loss: 0.0411
# Epoch 7843/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.8592e-05 - val_loss: 0.0410
# Epoch 7844/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7125e-05 - val_loss: 0.0405
# Epoch 7845/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7456e-05 - val_loss: 0.0407
# Epoch 7846/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.2440e-05 - val_loss: 0.0409
# Epoch 7847/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.2568e-05 - val_loss: 0.0421
# Epoch 7848/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.0035e-05 - val_loss: 0.0396
# Epoch 7849/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.3463e-05 - val_loss: 0.0412
# Epoch 7850/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.4140e-05 - val_loss: 0.0413
# Epoch 7851/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.9878e-05 - val_loss: 0.0417
# Epoch 7852/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.6496e-05 - val_loss: 0.0411
# Epoch 7853/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.5512e-05 - val_loss: 0.0403
# Epoch 7854/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.4094e-05 - val_loss: 0.0400
# Epoch 7855/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.4059e-05 - val_loss: 0.0404
# Epoch 7856/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.0951e-05 - val_loss: 0.0405
# Epoch 7857/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.5259e-05 - val_loss: 0.0404
# Epoch 7858/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.3576e-05 - val_loss: 0.0392
# Epoch 7859/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.3626e-05 - val_loss: 0.0381
# Epoch 7860/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.9597e-05 - val_loss: 0.0382
# Epoch 7861/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.2986e-05 - val_loss: 0.0395
# Epoch 7862/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.1344e-05 - val_loss: 0.0410
# Epoch 7863/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.0644e-05 - val_loss: 0.0402
# Epoch 7864/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.0196e-05 - val_loss: 0.0403
# Epoch 7865/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.3022e-05 - val_loss: 0.0398
# Epoch 7866/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.9140e-05 - val_loss: 0.0400
# Epoch 7867/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.9272e-05 - val_loss: 0.0386
# Epoch 7868/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.0699e-05 - val_loss: 0.0379
# Epoch 7869/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.9168e-05 - val_loss: 0.0377
# Epoch 7870/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.6272e-05 - val_loss: 0.0377
# Epoch 7871/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.1029e-05 - val_loss: 0.0388
# Epoch 7872/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.4880e-05 - val_loss: 0.0386
# Epoch 7873/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.2653e-05 - val_loss: 0.0380
# Epoch 7874/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.9592e-05 - val_loss: 0.0382
# Epoch 7875/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.1316e-05 - val_loss: 0.0392
# Epoch 7876/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.9413e-05 - val_loss: 0.0396
# Epoch 7877/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.3919e-05 - val_loss: 0.0400
# Epoch 7878/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.0019e-05 - val_loss: 0.0400
# Epoch 7879/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.9453e-05 - val_loss: 0.0408
# Epoch 7880/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.5014e-05 - val_loss: 0.0401
# Epoch 7881/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.2863e-05 - val_loss: 0.0400
# Epoch 7882/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9333e-05 - val_loss: 0.0397
# Epoch 7883/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9422e-05 - val_loss: 0.0398
# Epoch 7884/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.8657e-05 - val_loss: 0.0400
# Epoch 7885/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9671e-05 - val_loss: 0.0399
# Epoch 7886/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.9502e-05 - val_loss: 0.0400
# Epoch 7887/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.0565e-05 - val_loss: 0.0399
# Epoch 7888/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2139e-05 - val_loss: 0.0401
# Epoch 7889/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2997e-05 - val_loss: 0.0405
# Epoch 7890/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0946e-05 - val_loss: 0.0403
# Epoch 7891/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.0427e-05 - val_loss: 0.0397
# Epoch 7892/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0053e-05 - val_loss: 0.0389
# Epoch 7893/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0480e-05 - val_loss: 0.0387
# Epoch 7894/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.0742e-05 - val_loss: 0.0389
# Epoch 7895/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.0256e-05 - val_loss: 0.0395
# Epoch 7896/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.1181e-05 - val_loss: 0.0400
# Epoch 7897/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.1757e-05 - val_loss: 0.0400
# Epoch 7898/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0634e-05 - val_loss: 0.0404
# Epoch 7899/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.0518e-05 - val_loss: 0.0408
# Epoch 7900/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.0853e-05 - val_loss: 0.0406
# Epoch 7901/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0311e-05 - val_loss: 0.0403
# Epoch 7902/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9898e-05 - val_loss: 0.0400
# Epoch 7903/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.9275e-05 - val_loss: 0.0399
# Epoch 7904/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8400e-05 - val_loss: 0.0396
# Epoch 7905/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.8090e-05 - val_loss: 0.0391
# Epoch 7906/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8397e-05 - val_loss: 0.0390
# Epoch 7907/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8255e-05 - val_loss: 0.0395
# Epoch 7908/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7902e-05 - val_loss: 0.0401
# Epoch 7909/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.7959e-05 - val_loss: 0.0403
# Epoch 7910/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.9571e-05 - val_loss: 0.0398
# Epoch 7911/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.1915e-05 - val_loss: 0.0398
# Epoch 7912/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.1664e-05 - val_loss: 0.0400
# Epoch 7913/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.0070e-05 - val_loss: 0.0411
# Epoch 7914/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9678e-05 - val_loss: 0.0409
# Epoch 7915/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.9742e-05 - val_loss: 0.0403
# Epoch 7916/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.0063e-05 - val_loss: 0.0406
# Epoch 7917/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1179e-05 - val_loss: 0.0405
# Epoch 7918/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8967e-05 - val_loss: 0.0414
# Epoch 7919/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0084e-05 - val_loss: 0.0410
# Epoch 7920/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9941e-05 - val_loss: 0.0406
# Epoch 7921/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7638e-05 - val_loss: 0.0405
# Epoch 7922/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6721e-05 - val_loss: 0.0403
# Epoch 7923/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9204e-05 - val_loss: 0.0398
# Epoch 7924/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.9424e-05 - val_loss: 0.0401
# Epoch 7925/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.1534e-05 - val_loss: 0.0418
# Epoch 7926/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.0411e-05 - val_loss: 0.0420
# Epoch 7927/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8368e-05 - val_loss: 0.0413
# Epoch 7928/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.8309e-05 - val_loss: 0.0405
# Epoch 7929/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.0123e-05 - val_loss: 0.0389
# Epoch 7930/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.9765e-05 - val_loss: 0.0394
# Epoch 7931/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.1074e-05 - val_loss: 0.0393
# Epoch 7932/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.9147e-05 - val_loss: 0.0404
# Epoch 7933/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.6872e-05 - val_loss: 0.0412
# Epoch 7934/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.7471e-05 - val_loss: 0.0403
# Epoch 7935/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.4034e-05 - val_loss: 0.0401
# Epoch 7936/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.9366e-05 - val_loss: 0.0404
# Epoch 7937/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.5873e-05 - val_loss: 0.0402
# Epoch 7938/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.8288e-05 - val_loss: 0.0411
# Epoch 7939/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.4918e-05 - val_loss: 0.0409
# Epoch 7940/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.3891e-05 - val_loss: 0.0406
# Epoch 7941/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.0378e-05 - val_loss: 0.0414
# Epoch 7942/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.1280e-05 - val_loss: 0.0418
# Epoch 7943/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.0734e-05 - val_loss: 0.0421
# Epoch 7944/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.0228e-05 - val_loss: 0.0435
# Epoch 7945/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.4403e-05 - val_loss: 0.0415
# Epoch 7946/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.0560e-05 - val_loss: 0.0423
# Epoch 7947/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.2133e-05 - val_loss: 0.0405
# Epoch 7948/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.7481e-05 - val_loss: 0.0424
# Epoch 7949/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.0103e-05 - val_loss: 0.0415
# Epoch 7950/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.5449e-05 - val_loss: 0.0400
# Epoch 7951/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0431e-05 - val_loss: 0.0408
# Epoch 7952/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.1063e-05 - val_loss: 0.0401
# Epoch 7953/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.4031e-05 - val_loss: 0.0408
# Epoch 7954/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.3120e-05 - val_loss: 0.0407
# Epoch 7955/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.3138e-05 - val_loss: 0.0407
# Epoch 7956/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0567e-05 - val_loss: 0.0417
# Epoch 7957/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.1142e-05 - val_loss: 0.0418
# Epoch 7958/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.0188e-05 - val_loss: 0.0417
# Epoch 7959/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1555e-05 - val_loss: 0.0409
# Epoch 7960/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.8556e-05 - val_loss: 0.0412
# Epoch 7961/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.9530e-05 - val_loss: 0.0417
# Epoch 7962/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.0627e-05 - val_loss: 0.0411
# Epoch 7963/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7354e-05 - val_loss: 0.0408
# Epoch 7964/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.8255e-05 - val_loss: 0.0407
# Epoch 7965/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.8201e-05 - val_loss: 0.0415
# Epoch 7966/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2389e-05 - val_loss: 0.0411
# Epoch 7967/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.2901e-05 - val_loss: 0.0401
# Epoch 7968/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.9399e-05 - val_loss: 0.0395
# Epoch 7969/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.8865e-05 - val_loss: 0.0402
# Epoch 7970/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.4689e-05 - val_loss: 0.0406
# Epoch 7971/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.9782e-05 - val_loss: 0.0425
# Epoch 7972/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.1247e-05 - val_loss: 0.0420
# Epoch 7973/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.2760e-05 - val_loss: 0.0410
# Epoch 7974/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.6544e-05 - val_loss: 0.0397
# Epoch 7975/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.
/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.0454e-05 - val_loss: 0.0460
# Epoch 9954/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1791e-05 - val_loss: 0.0469
# Epoch 9955/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.0613e-05 - val_loss: 0.0455
# Epoch 9956/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2910e-05 - val_loss: 0.0474
# Epoch 9957/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.0366e-05 - val_loss: 0.0465
# Epoch 9958/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7499e-05 - val_loss: 0.0460
# Epoch 9959/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6027e-05 - val_loss: 0.0459
# Epoch 9960/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2430e-05 - val_loss: 0.0453
# Epoch 9961/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1594e-05 - val_loss: 0.0455
# Epoch 9962/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9718e-05 - val_loss: 0.0460
# Epoch 9963/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0061e-05 - val_loss: 0.0457
# Epoch 9964/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8286e-05 - val_loss: 0.0450
# Epoch 9965/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8135e-05 - val_loss: 0.0457
# Epoch 9966/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5931e-05 - val_loss: 0.0454
# Epoch 9967/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6399e-05 - val_loss: 0.0459
# Epoch 9968/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6067e-05 - val_loss: 0.0458
# Epoch 9969/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5926e-05 - val_loss: 0.0454
# Epoch 9970/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6603e-05 - val_loss: 0.0458
# Epoch 9971/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7001e-05 - val_loss: 0.0459
# Epoch 9972/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7204e-05 - val_loss: 0.0463
# Epoch 9973/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7402e-05 - val_loss: 0.0456
# Epoch 9974/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7281e-05 - val_loss: 0.0466
# Epoch 9975/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7669e-05 - val_loss: 0.0457
# Epoch 9976/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.7465e-05 - val_loss: 0.0465
# Epoch 9977/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.8464e-05 - val_loss: 0.0455
# Epoch 9978/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.8638e-05 - val_loss: 0.0458
# Epoch 9979/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.8882e-05 - val_loss: 0.0451
# Epoch 9980/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.7392e-05 - val_loss: 0.0452
# Epoch 9981/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7392e-05 - val_loss: 0.0457
# Epoch 9982/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.7326e-05 - val_loss: 0.0457
# Epoch 9983/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7484e-05 - val_loss: 0.0458
# Epoch 9984/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7111e-05 - val_loss: 0.0452
# Epoch 9985/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7565e-05 - val_loss: 0.0456
# Epoch 9986/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7425e-05 - val_loss: 0.0452
# Epoch 9987/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.7280e-05 - val_loss: 0.0456
# Epoch 9988/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6911e-05 - val_loss: 0.0454
# Epoch 9989/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7483e-05 - val_loss: 0.0451
# Epoch 9990/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.7449e-05 - val_loss: 0.0454
# Epoch 9991/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.7198e-05 - val_loss: 0.0450
# Epoch 9992/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8101e-05 - val_loss: 0.0453
# Epoch 9993/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.8391e-05 - val_loss: 0.0447
# Epoch 9994/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9015e-05 - val_loss: 0.0450
# Epoch 9995/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9668e-05 - val_loss: 0.0452
# Epoch 9996/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0921e-05 - val_loss: 0.0452
# Epoch 9997/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.3007e-05 - val_loss: 0.0452
# Epoch 9998/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.2726e-05 - val_loss: 0.0454
# Epoch 9999/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5254e-05 - val_loss: 0.0476
# Epoch 10000/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1071e-05 - val_loss: 0.0453
# --- Starting Reinforcement Learning Fine-Tuning (Batched) ---
# RL Epoch 1/150, Average Loss per Batch: 0.000041
# RL Epoch 2/150, Average Loss per Batch: 0.000024
# RL Epoch 3/150, Average Loss per Batch: 0.000016
# RL Epoch 4/150, Average Loss per Batch: 0.000014
# RL Epoch 5/150, Average Loss per Batch: 0.000016
# RL Epoch 6/150, Average Loss per Batch: 0.000022
# RL Epoch 7/150, Average Loss per Batch: 0.000030
# RL Epoch 8/150, Average Loss per Batch: 0.000035
# RL Epoch 9/150, Average Loss per Batch: 0.000033
# RL Epoch 10/150, Average Loss per Batch: 0.000025
# RL Epoch 11/150, Average Loss per Batch: 0.000023
# RL Epoch 12/150, Average Loss per Batch: 0.000023
# RL Epoch 13/150, Average Loss per Batch: 0.000023
# RL Epoch 14/150, Average Loss per Batch: 0.000022
# RL Epoch 15/150, Average Loss per Batch: 0.000021
# RL Epoch 16/150, Average Loss per Batch: 0.000021
# RL Epoch 17/150, Average Loss per Batch: 0.000021
# RL Epoch 18/150, Average Loss per Batch: 0.000022
# RL Epoch 19/150, Average Loss per Batch: 0.000022
# RL Epoch 20/150, Average Loss per Batch: 0.000023
# RL Epoch 21/150, Average Loss per Batch: 0.000023
# RL Epoch 22/150, Average Loss per Batch: 0.000023
# RL Epoch 23/150, Average Loss per Batch: 0.000024
# RL Epoch 24/150, Average Loss per Batch: 0.000022
# RL Epoch 25/150, Average Loss per Batch: 0.000021
# RL Epoch 26/150, Average Loss per Batch: 0.000021
# RL Epoch 27/150, Average Loss per Batch: 0.000021
# RL Epoch 28/150, Average Loss per Batch: 0.000021
# RL Epoch 29/150, Average Loss per Batch: 0.000023
# RL Epoch 30/150, Average Loss per Batch: 0.000024
# RL Epoch 31/150, Average Loss per Batch: 0.000027
# RL Epoch 32/150, Average Loss per Batch: 0.000031
# RL Epoch 33/150, Average Loss per Batch: 0.000032
# RL Epoch 34/150, Average Loss per Batch: 0.000038
# RL Epoch 35/150, Average Loss per Batch: 0.000034
# RL Epoch 36/150, Average Loss per Batch: 0.000036
# RL Epoch 37/150, Average Loss per Batch: 0.000031
# RL Epoch 38/150, Average Loss per Batch: 0.000029
# RL Epoch 39/150, Average Loss per Batch: 0.000026
# RL Epoch 40/150, Average Loss per Batch: 0.000025
# RL Epoch 41/150, Average Loss per Batch: 0.000025
# RL Epoch 42/150, Average Loss per Batch: 0.000023
# RL Epoch 43/150, Average Loss per Batch: 0.000023
# RL Epoch 44/150, Average Loss per Batch: 0.000021
# RL Epoch 45/150, Average Loss per Batch: 0.000020
# RL Epoch 46/150, Average Loss per Batch: 0.000019
# RL Epoch 47/150, Average Loss per Batch: 0.000019
# RL Epoch 48/150, Average Loss per Batch: 0.000020
# RL Epoch 49/150, Average Loss per Batch: 0.000021
# RL Epoch 50/150, Average Loss per Batch: 0.000024
# RL Epoch 51/150, Average Loss per Batch: 0.000027
# RL Epoch 52/150, Average Loss per Batch: 0.000030
# RL Epoch 53/150, Average Loss per Batch: 0.000034
# RL Epoch 54/150, Average Loss per Batch: 0.000034
# RL Epoch 55/150, Average Loss per Batch: 0.000036
# RL Epoch 56/150, Average Loss per Batch: 0.000032
# RL Epoch 57/150, Average Loss per Batch: 0.000032
# RL Epoch 58/150, Average Loss per Batch: 0.000027
# RL Epoch 59/150, Average Loss per Batch: 0.000025
# RL Epoch 60/150, Average Loss per Batch: 0.000022
# RL Epoch 61/150, Average Loss per Batch: 0.000020
# RL Epoch 62/150, Average Loss per Batch: 0.000019
# RL Epoch 63/150, Average Loss per Batch: 0.000018
# RL Epoch 64/150, Average Loss per Batch: 0.000017
# RL Epoch 65/150, Average Loss per Batch: 0.000017
# RL Epoch 66/150, Average Loss per Batch: 0.000016
# RL Epoch 67/150, Average Loss per Batch: 0.000017
# RL Epoch 68/150, Average Loss per Batch: 0.000016
# RL Epoch 69/150, Average Loss per Batch: 0.000016
# RL Epoch 70/150, Average Loss per Batch: 0.000016
# RL Epoch 71/150, Average Loss per Batch: 0.000016
# RL Epoch 72/150, Average Loss per Batch: 0.000016
# RL Epoch 73/150, Average Loss per Batch: 0.000017
# RL Epoch 74/150, Average Loss per Batch: 0.000017
# RL Epoch 75/150, Average Loss per Batch: 0.000017
# RL Epoch 76/150, Average Loss per Batch: 0.000018
# RL Epoch 77/150, Average Loss per Batch: 0.000018
# RL Epoch 78/150, Average Loss per Batch: 0.000019
# RL Epoch 79/150, Average Loss per Batch: 0.000019
# RL Epoch 80/150, Average Loss per Batch: 0.000020
# RL Epoch 81/150, Average Loss per Batch: 0.000019
# RL Epoch 82/150, Average Loss per Batch: 0.000020
# RL Epoch 83/150, Average Loss per Batch: 0.000021
# RL Epoch 84/150, Average Loss per Batch: 0.000023
# RL Epoch 85/150, Average Loss per Batch: 0.000024
# RL Epoch 86/150, Average Loss per Batch: 0.000028
# RL Epoch 87/150, Average Loss per Batch: 0.000029
# RL Epoch 88/150, Average Loss per Batch: 0.000032
# RL Epoch 89/150, Average Loss per Batch: 0.000035
# RL Epoch 90/150, Average Loss per Batch: 0.000038
# RL Epoch 91/150, Average Loss per Batch: 0.000048
# RL Epoch 92/150, Average Loss per Batch: 0.000047
# RL Epoch 93/150, Average Loss per Batch: 0.000055
# RL Epoch 94/150, Average Loss per Batch: 0.000048
# RL Epoch 95/150, Average Loss per Batch: 0.000043
# RL Epoch 96/150, Average Loss per Batch: 0.000036
# RL Epoch 97/150, Average Loss per Batch: 0.000025
# RL Epoch 98/150, Average Loss per Batch: 0.000021
# RL Epoch 99/150, Average Loss per Batch: 0.000017
# RL Epoch 100/150, Average Loss per Batch: 0.000015
# RL Epoch 101/150, Average Loss per Batch: 0.000014
# RL Epoch 102/150, Average Loss per Batch: 0.000013
# RL Epoch 103/150, Average Loss per Batch: 0.000013
# RL Epoch 104/150, Average Loss per Batch: 0.000012
# RL Epoch 105/150, Average Loss per Batch: 0.000012
# RL Epoch 106/150, Average Loss per Batch: 0.000012
# RL Epoch 107/150, Average Loss per Batch: 0.000012
# RL Epoch 108/150, Average Loss per Batch: 0.000012
# RL Epoch 109/150, Average Loss per Batch: 0.000013
# RL Epoch 110/150, Average Loss per Batch: 0.000014
# RL Epoch 111/150, Average Loss per Batch: 0.000015
# RL Epoch 112/150, Average Loss per Batch: 0.000014
# RL Epoch 113/150, Average Loss per Batch: 0.000015
# RL Epoch 114/150, Average Loss per Batch: 0.000015
# RL Epoch 115/150, Average Loss per Batch: 0.000017
# RL Epoch 116/150, Average Loss per Batch: 0.000018
# RL Epoch 117/150, Average Loss per Batch: 0.000020
# RL Epoch 118/150, Average Loss per Batch: 0.000023
# RL Epoch 119/150, Average Loss per Batch: 0.000027
# RL Epoch 120/150, Average Loss per Batch: 0.000032
# RL Epoch 121/150, Average Loss per Batch: 0.000037
# RL Epoch 122/150, Average Loss per Batch: 0.000044
# RL Epoch 123/150, Average Loss per Batch: 0.000045
# RL Epoch 124/150, Average Loss per Batch: 0.000052
# RL Epoch 125/150, Average Loss per Batch: 0.000043
# RL Epoch 126/150, Average Loss per Batch: 0.000043
# RL Epoch 127/150, Average Loss per Batch: 0.000034
# RL Epoch 128/150, Average Loss per Batch: 0.000031
# RL Epoch 129/150, Average Loss per Batch: 0.000026
# RL Epoch 130/150, Average Loss per Batch: 0.000022
# RL Epoch 131/150, Average Loss per Batch: 0.000019
# RL Epoch 132/150, Average Loss per Batch: 0.000018
# RL Epoch 133/150, Average Loss per Batch: 0.000017
# RL Epoch 134/150, Average Loss per Batch: 0.000018
# RL Epoch 135/150, Average Loss per Batch: 0.000018
# RL Epoch 136/150, Average Loss per Batch: 0.000019
# RL Epoch 137/150, Average Loss per Batch: 0.000020
# RL Epoch 138/150, Average Loss per Batch: 0.000022
# RL Epoch 139/150, Average Loss per Batch: 0.000023
# RL Epoch 140/150, Average Loss per Batch: 0.000024
# RL Epoch 141/150, Average Loss per Batch: 0.000025
# RL Epoch 142/150, Average Loss per Batch: 0.000025
# RL Epoch 143/150, Average Loss per Batch: 0.000026
# RL Epoch 144/150, Average Loss per Batch: 0.000025
# RL Epoch 145/150, Average Loss per Batch: 0.000025
# RL Epoch 146/150, Average Loss per Batch: 0.000022
# RL Epoch 147/150, Average Loss per Batch: 0.000022
# RL Epoch 148/150, Average Loss per Batch: 0.000020
# RL Epoch 149/150, Average Loss per Batch: 0.000020
# RL Epoch 150/150, Average Loss per Batch: 0.000018
# --- RL Fine-Tuning Complete ---
#
#  Training Set Performance Metrics (LSTM):
#  Mean Absolute Error (MAE) : ₹4.28
#  Mean Squared Error (MSE)  : ₹31.73
#  Root Squared Error (RMSE) : ₹5.63
#  R² Score                  : 0.9992
#  Mean Absolute Percentage Error (MAPE) : 0.32%
#  Accuracy (100 - MAPE) : 99.68%
#  MSE Percentage of Average Price : 2.28%
#  MAE Percentage of Average Price : 0.31%
#
#  Validation Set Performance Metrics (LSTM):
#  Mean Absolute Error (MAE) : ₹251.07
#  Mean Squared Error (MSE)  : ₹85572.79
#  Root Squared Error (RMSE) : ₹292.53
#  R² Score                  : -2.4188
#  Mean Absolute Percentage Error (MAPE) : 13.82%
#  Accuracy (100 - MAPE) : 86.18%
#  MSE Percentage of Average Price: 4914.62%
#  MAE Percentage of Average Price: 14.42%
#
#  Prediction for 2025-06-18:
#  Predicted Closing Price: ₹1538.36
#  Actual Closing Price   : ₹1632.9000244140625
#  Test Set Performance Metrics (LSTM):
#  Mean Absolute Error (MAE) : ₹41.14
#  Mean Squared Error (MSE)  : ₹2838.51
#  Root Squared Error (RMSE) : ₹53.28
#  R² Score                  : -2.3291
#  Mean Absolute Percentage Error (MAPE) : 2.55%
#  Accuracy (100 - MAPE) : 97.45%
#  MSE Percentage of Average Price: 177.83%
#  MAE Percentage of Average Price: 2.58%

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import SimpleRNN, LSTM
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
from matplotlib.dates import DateFormatter
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
import numpy as np
import pandas as pd
import datetime
import holidays
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import warnings

warnings.filterwarnings('ignore')

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

SYMBOL = "INFY.NS"
SEQUENCE_LENGTH = 60

TRAIN_START_DATE = "2020-06-01"
TRAIN_END_DATE = "2025-05-31"

TEST_START_DATE = "2025-06-01"
TEST_END_DATE = "2025-07-01"

# Get Indian trading holidays
def get_nse_holidays():
    in_holidays = holidays.India(years=range(2020, 2026))
    return set(in_holidays.keys())

TRADING_HOLIDAYS = get_nse_holidays()

def is_valid_date(date_str):
    try:
        date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()
        if not (datetime.date(2025, 6, 1) <= date <= datetime.date(2025, 7, 1)):
            print("Date must be between 2025-06-01 and 2025-07-01.")
            return False
        if date.weekday() >= 5:
            print("Weekends are not trading days.")
            return False
        if date in TRADING_HOLIDAYS:
            print("Entered date is a trading holiday.")
            return False
        return True
    except ValueError:
        print("Invalid date format. Use YYYY-MM-DD.")
        return False

def get_stock_data():
    print("Fetching data from Yahoo Finance...")
    full_df = yf.download(SYMBOL, start=TRAIN_START_DATE, end=TEST_END_DATE)
    full_df = full_df[['Close']]
    full_df.dropna(inplace=True)
    full_df.index = pd.to_datetime(full_df.index)

    train_df = full_df.loc[TRAIN_START_DATE:TRAIN_END_DATE]
    test_df = full_df.loc[TEST_START_DATE:TEST_END_DATE]
    return train_df, test_df, full_df

# Prompt until valid date is entered
def get_user_date():
    while True:
        date_input = input("Enter a date (YYYY-MM-DD): ")
        if is_valid_date(date_input):
            return datetime.datetime.strptime(date_input, "%Y-%m-%d").date()

# Build the LSTM model
def build_model(input_shape, learning_rate=0.001): # Added learning_rate parameter
    model = Sequential()
    model.add(LSTM(units=50, activation='tanh', input_shape=input_shape))
    model.add(Dense(1))
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# Reinforcement Learning Fine-Tuning
class RLAgent:
    """
    A simple RL Agent to fine-tune the RNN model.
    The "environment" is the time series data, and the "action" is the prediction.
    The reward is based on prediction accuracy.
    """
    def __init__(self, model, learning_rate=0.001):
        self.model = model
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

    @tf.function
    def train_step(self, state, target):
        """
        Performs a single training step to fine-tune the model weights.
        """
        with tf.GradientTape() as tape:
            prediction = self.model(state, training=True)
            # Use Mean Squared Error directly as the loss to minimize
            loss = tf.reduce_mean(tf.square(tf.cast(target, tf.float32) - prediction))

        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))
        return loss # Return the mean loss for the batch


def fine_tune_with_rl(model, X_train, y_train, epochs=5, learning_rate=0.001, batch_size=32):
    """
    Fine- tunes the pre-trained RNN model using a simple reinforcement learning loop with batched data.
    """
    print("\n--- Starting Reinforcement Learning Fine-Tuning (Batched) ---")
    agent = RLAgent(model, learning_rate=learning_rate)

    # Create a TensorFlow Dataset and batch it
    dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
    dataset = dataset.batch(batch_size)

    num_batches = tf.data.experimental.cardinality(dataset).numpy()

    for epoch in range(epochs):
        total_loss = 0
        batch_count = 0
        for batch_x, batch_y in dataset:
            # Ensure batch_x has the correct shape (batch_size, sequence_length, 1)
            batch_x_reshaped = tf.reshape(batch_x, (tf.shape(batch_x)[0], tf.shape(batch_x)[1], 1))
            loss = agent.train_step(batch_x_reshaped, batch_y)
            total_loss += loss.numpy() # Sum up the mean loss for each batch
            batch_count += 1

        # Calculate average loss per epoch
        average_epoch_loss = total_loss / num_batches if num_batches > 0 else 0
        print(f"RL Epoch {epoch + 1}/{epochs}, Average Loss per Batch: {average_epoch_loss:.6f}") # Print average loss

    print("--- RL Fine-Tuning Complete ---")
    return model


def create_test_sequences(train_df, test_df, scaler):
    combined = pd.concat([train_df, test_df])
    scaled = scaler.transform(combined[['Close']])
    X_test = []
    test_dates = test_df.index.date

    for i in range(len(train_df), len(combined)):
        if i - SEQUENCE_LENGTH < 0:
            continue
        seq = scaled[i - SEQUENCE_LENGTH:i]
        X_test.append(seq)

    X_test = np.array(X_test)
    return X_test, test_dates

def predict_price_on_test(model, full_df, scaler, user_date):
    all_dates = full_df.index.date
    try:
        idx = list(all_dates).index(user_date)
    except ValueError:
        print("User date not found in data.")
        return None, None, user_date

    if idx < SEQUENCE_LENGTH:
        print("Not enough data to predict for this date.")
        return None, None, user_date

    input_seq = scaler.transform(full_df[['Close']].values)[idx - SEQUENCE_LENGTH:idx]
    input_seq = np.reshape(input_seq, (1, SEQUENCE_LENGTH, 1))

    predicted_scaled = model.predict(input_seq, verbose=0)
    predicted_price = scaler.inverse_transform(predicted_scaled)[0][0]

    actual_price = float(full_df.iloc[idx]['Close']) if idx < len(full_df) else None
    return predicted_price, actual_price, full_df.index[idx].date()

# Plot the result
def plot_results(df, predicted_date, predicted_price, actual_price):
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['Close'], label='Historical Close Price',zorder=1)
    #plt.axvline(pd.to_datetime(predicted_date), color='red', linestyle='--', label='Predicted Date')
    plt.scatter(pd.to_datetime(predicted_date), predicted_price, color='orange', label='Predicted Price',zorder=2)
    if actual_price is not None:
        plt.scatter(pd.to_datetime(predicted_date), actual_price, color='green', label='Actual Price',zorder=3, s=100)
    plt.title("INFOSYS Stock Price with Prediction (yfinance)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

#Plotting error with no. of epochs
def plot_training_loss(history):
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title("Training and Validation Loss Over Epochs (LSTM)") # Changed title
    plt.xlabel("Epoch no.")
    plt.ylabel("Loss (MSE)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def main():
    print("=== INFOSYS LSTM Stock Price Predictor (Test Phase June–July 2025) ===") # Changed title
    user_date = get_user_date()

    # Step 1: Get stock data
    train_df, test_df, full_df = get_stock_data()

    # Step 2: Preprocess
    scaler = MinMaxScaler()
    scaled_train = scaler.fit_transform(train_df[['Close']])
    X, y = [], []
    for i in range(SEQUENCE_LENGTH, len(scaled_train)):
        X.append(scaled_train[i - SEQUENCE_LENGTH:i])
        y.append(scaled_train[i])
    X = np.array(X)
    y = np.array(y)

    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)
    #early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
    # Step 3: Build and train model
    model = build_model((X_train.shape[1], 1), learning_rate=0.0005) # Reduced Adam learning rate
    print("Training LSTM model...") # Changed print statement
    history = model.fit(X_train, y_train, epochs=10000, batch_size=64, validation_data=(X_val, y_val), verbose = 1) #callbacks = [early_stop], verbose=1)

    #print(f"\nBest weights restored from epoch: {early_stop.best_epoch + 1}")

    # Step 4: Plot training loss
    plot_training_loss(history)

    # Step 5: Fine-tune with Reinforcement Learning
    rl_tuned_model = fine_tune_with_rl(model, X_train, y_train, epochs=200, learning_rate=0.0001, batch_size=32)

    # Predict on training data to evaluate performance
    y_train_pred_scaled = rl_tuned_model.predict(X_train, verbose=0)
    y_train_pred = scaler.inverse_transform(y_train_pred_scaled)
    y_true_train = scaler.inverse_transform(y_train.reshape(-1, 1))

    # Calculate and print training metrics
    mae_train = mean_absolute_error(y_true_train, y_train_pred)
    mse_train = mean_squared_error(y_true_train, y_train_pred)
    rmse_train = np.sqrt(mse_train)
    r2_train = r2_score(y_true_train, y_train_pred)
    mape_train = mean_absolute_percentage_error(y_true_train, y_train_pred) * 100
    accuracy_train = 100 - mape_train
    mse_percent_train = (mse_train / np.mean(y_true_train)) * 100 if np.mean(y_true_train) != 0 else np.nan
    mae_percent_train = (mae_train / np.mean(y_true_train)) * 100 if np.mean(y_true_train) != 0 else np.nan
    print("\n Training Set Performance Metrics (LSTM):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_train:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_train:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_train:.2f}")
    print(f" R² Score                  : {r2_train:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_train:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_train:.2f}%")
    print(f" MSE Percentage of Average Price : {mse_percent_train:.2f}%")
    print(f" MAE Percentage of Average Price : {mae_percent_train:.2f}%")

    # Predict on validation set
    y_val_pred_scaled = rl_tuned_model.predict(X_val, verbose=0)
    y_val_pred = scaler.inverse_transform(y_val_pred_scaled)
    y_val_true = scaler.inverse_transform(y_val.reshape(-1, 1))

    # Calculate and print validation metrics
    mae_val = mean_absolute_error(y_val_true, y_val_pred)
    mse_val = mean_squared_error(y_val_true, y_val_pred)
    rmse_val = np.sqrt(mse_val)
    r2_val = r2_score(y_val_true, y_val_pred)
    mape_val = mean_absolute_percentage_error(y_val_true, y_val_pred) * 100
    accuracy_val = 100 - mape_val
    mse_percent_val = (mse_val / np.mean(y_val_true)) * 100 if np.mean(y_val_true) != 0 else np.nan
    mae_percent_val = (mae_val / np.mean(y_val_true)) * 100 if np.mean(y_val_true) != 0 else np.nan
    print("\n Validation Set Performance Metrics (LSTM):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_val:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_val:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_val:.2f}")
    print(f" R² Score                  : {r2_val:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_val:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_val:.2f}%")
    print(f" MSE Percentage of Average Price: {mse_percent_val:.2f}%")
    print(f" MAE Percentage of Average Price: {mae_percent_val:.2f}%")


    # Step 6: Predict for user-input test date
    predicted_price, actual_price, predicted_date = predict_price_on_test(rl_tuned_model, full_df, scaler, user_date)
    if predicted_price is not None:
        print(f"\n Prediction for {predicted_date}:")
        print(f" Predicted Closing Price: ₹{predicted_price:.2f}")
        if actual_price is not None:
            print(f" Actual Closing Price   : ₹{actual_price}")
        else:
            print("Actual price not available.")

        plot_results(full_df, predicted_date, predicted_price, actual_price)
    else:
        print("❌ Unable to make prediction.")

    # === Step 7: Predict all test dates and compare ===

    # Reuse combined full_df
    combined_df = pd.concat([train_df, test_df])
    scaled_combined = scaler.transform(combined_df[['Close']])

    X_test_all = []
    test_date_indexes = []

    for i in range(len(train_df), len(combined_df)):
        if i - SEQUENCE_LENGTH < 0:
            continue
        seq = scaled_combined[i - SEQUENCE_LENGTH:i]
        X_test_all.append(seq)
        test_date_indexes.append(combined_df.index[i])

    X_test_all = np.array(X_test_all)

    # Predict on test sequences
    y_test_pred_scaled = rl_tuned_model.predict(X_test_all, verbose=0)
    y_test_pred = scaler.inverse_transform(y_test_pred_scaled)

    # Actual prices
    y_test_true = test_df.loc[test_date_indexes, 'Close'].values

    # Calculate and print test metrics
    mae_test = mean_absolute_error(y_test_true, y_test_pred)
    mse_test = mean_squared_error(y_test_true, y_test_pred)
    rmse_test = np.sqrt(mse_test)
    r2_test = r2_score(y_test_true, y_test_pred)
    mape_test = mean_absolute_percentage_error(y_test_true, y_test_pred) * 100
    accuracy_test = 100 - mape_test
    mse_percent_test = (mse_test / np.mean(y_test_true)) * 100 if np.mean(y_test_true) != 0 else np.nan
    mae_percent_test = (mae_test / np.mean(y_test_true)) * 100 if np.mean(y_test_true) != 0 else np.nan
    print("\n Test Set Performance Metrics (LSTM):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_test:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_test:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_test:.2f}")
    print(f" R² Score                  : {r2_test:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_test:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_test:.2f}%")
    print(f" MSE Percentage of Average Price: {mse_percent_test:.2f}%")
    print(f" MAE Percentage of Average Price: {mae_percent_test:.2f}%")

    # Plot actual vs predicted
    plt.figure(figsize=(12, 6))
    plt.plot(test_date_indexes, y_test_true, label='Actual Price')
    plt.plot(test_date_indexes, y_test_pred, label='Predicted Price')
    plt.title("Actual vs Predicted INFY Closing Prices (01-Jun to 01-Jul 2025) (LSTM)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.xticks(rotation=45)
    plt.gca().xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# === INFOSYS LSTM Stock Price Predictor (Test Phase June–July 2025) ===
# [*********************100%***********************]  1 of 1 completed
# Fetching data from Yahoo Finance...
# Training LSTM model...
# Epoch 1/10000
# Streaming output truncated to the last 5000 lines.
# Epoch 7501/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.9559e-05 - val_loss: 0.0292
# Epoch 7502/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.6501e-05 - val_loss: 0.0292
# Epoch 7503/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.7225e-05 - val_loss: 0.0299
# Epoch 7504/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.3883e-05 - val_loss: 0.0298
# Epoch 7505/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.3835e-05 - val_loss: 0.0281
# Epoch 7506/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.4990e-05 - val_loss: 0.0271
# Epoch 7507/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.6288e-05 - val_loss: 0.0276
# Epoch 7508/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.6593e-05 - val_loss: 0.0273
# Epoch 7509/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.7641e-05 - val_loss: 0.0274
# Epoch 7510/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.4921e-05 - val_loss: 0.0287
# Epoch 7511/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.4990e-05 - val_loss: 0.0280
# Epoch 7512/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.3918e-05 - val_loss: 0.0270
# Epoch 7513/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.6933e-05 - val_loss: 0.0272
# Epoch 7514/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.2296e-05 - val_loss: 0.0267
# Epoch 7515/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.5440e-05 - val_loss: 0.0278
# Epoch 7516/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.5237e-05 - val_loss: 0.0274
# Epoch 7517/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.5297e-05 - val_loss: 0.0269
# Epoch 7518/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.8488e-05 - val_loss: 0.0276
# Epoch 7519/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.8124e-05 - val_loss: 0.0271
# Epoch 7520/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.5608e-05 - val_loss: 0.0272
# Epoch 7521/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.
10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.1703e-05 - val_loss: 0.0291
# Epoch 7951/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.1745e-05 - val_loss: 0.0285
# Epoch 7952/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.1647e-05 - val_loss: 0.0289
# Epoch 7953/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.1712e-05 - val_loss: 0.0289
# Epoch 7954/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2159e-05 - val_loss: 0.0289
# Epoch 7955/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.1077e-05 - val_loss: 0.0290
# Epoch 7956/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1545e-05 - val_loss: 0.0286
# Epoch 7957/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.1002e-05 - val_loss: 0.0295
# Epoch 7958/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.1801e-05 - val_loss: 0.0286
# Epoch 7959/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1246e-05 - val_loss: 0.0296
# Epoch 7960/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.1752e-05 - val_loss: 0.0288
# Epoch 7961/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0976e-05 - val_loss: 0.0294
# Epoch 7962/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1434e-05 - val_loss: 0.0287
# Epoch 7963/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1507e-05 - val_loss: 0.0295
# Epoch 7964/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.1679e-05 - val_loss: 0.0285
# Epoch 7965/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1264e-05 - val_loss: 0.0294
# Epoch 7966/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1525e-05 - val_loss: 0.0284
# Epoch 7967/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0346e-05 - val_loss: 0.0291
# Epoch 7968/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.1431e-05 - val_loss: 0.0286
# Epoch 7969/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.1691e-05 - val_loss: 0.0291
# Epoch 7970/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.2140e-05 - val_loss: 0.0285
# Epoch 7971/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.2613e-05 - val_loss: 0.0294
# Epoch 7972/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.1711e-05 - val_loss: 0.0286
# Epoch 7973/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0830e-05 - val_loss: 0.0296
# Epoch 7974/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1044e-05 - val_loss: 0.0290
# Epoch 7975/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1684e-05 - val_loss: 0.0298
# Epoch 7976/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.1551e-05 - val_loss: 0.0295
# Epoch 7977/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.1977e-05 - val_loss: 0.0304
# Epoch 7978/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.1242e-05 - val_loss: 0.0299
# Epoch 7979/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.1581e-05 - val_loss: 0.0306
# Epoch 7980/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.2930e-05 - val_loss: 0.0304
# Epoch 7981/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.4205e-05 - val_loss: 0.0308
# Epoch 7982/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.1887e-05 - val_loss: 0.0297
# Epoch 7983/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.3128e-05 - val_loss: 0.0305
# Epoch 7984/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.2836e-05 - val_loss: 0.0301
# Epoch 7985/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.3561e-05 - val_loss: 0.0304
# Epoch 7986/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2248e-05 - val_loss: 0.0300
# Epoch 7987/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.4669e-05 - val_loss: 0.0309
# Epoch 7988/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.3045e-05 - val_loss: 0.0302
# Epoch 7989/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.4478e-05 - val_loss: 0.0319
# Epoch 7990/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.3798e-05 - val_loss: 0.0306
# Epoch 7991/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.2609e-05 - val_loss: 0.0313
# Epoch 7992/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.0126e-05 - val_loss: 0.0309
# Epoch 7993/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9635e-05 - val_loss: 0.0301
# Epoch 7994/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9294e-05 - val_loss: 0.0303
# Epoch 7995/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.1231e-05 - val_loss: 0.0295
# Epoch 7996/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.3791e-05 - val_loss: 0.0306
# Epoch 7997/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.4669e-05 - val_loss: 0.0286
# Epoch 7998/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.3719e-05 - val_loss: 0.0307
# Epoch 7999/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.4572e-05 - val_loss: 0.0293
# Epoch 8000/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.5243e-05 - val_loss: 0.0318
# Epoch 8001/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.4971e-05 - val_loss: 0.0307
# Epoch 8002/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.3710e-05 - val_loss: 0.0304
# Epoch 8003/10000
# ...
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.8204e-05 - val_loss: 0.0314
# Epoch 9953/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7553e-05 - val_loss: 0.0322
# Epoch 9954/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.
# RL Epoch 6/200, Average Loss per Batch: 0.000020
# RL Epoch 7/200, Average Loss per Batch: 0.000021
# RL Epoch 8/200, Average Loss per Batch: 0.000025
# RL Epoch 9/200, Average Loss per Batch: 0.000033
# RL Epoch 10/200, Average Loss per Batch: 0.000039
# RL Epoch 11/200, Average Loss per Batch: 0.000039
# RL Epoch 12/200, Average Loss per Batch: 0.000036
# RL Epoch 13/200, Average Loss per Batch: 0.000034
# RL Epoch 14/200, Average Loss per Batch: 0.000028
# RL Epoch 15/200, Average Loss per Batch: 0.000028
# RL Epoch 16/200, Average Loss per Batch: 0.000023
# RL Epoch 17/200, Average Loss per Batch: 0.000020
# RL Epoch 18/200, Average Loss per Batch: 0.000018
# RL Epoch 19/200, Average Loss per Batch: 0.000019
# RL Epoch 20/200, Average Loss per Batch: 0.000016
# RL Epoch 21/200, Average Loss per Batch: 0.000016
# RL Epoch 22/200, Average Loss per Batch: 0.000016
# RL Epoch 23/200, Average Loss per Batch: 0.000017
# RL Epoch 24/200, Average Loss per Batch: 0.000016
# RL Epoch 25/200, Average Loss per Batch: 0.000017
# RL Epoch 26/200, Average Loss per Batch: 0.000018
# RL Epoch 27/200, Average Loss per Batch: 0.000019
# RL Epoch 28/200, Average Loss per Batch: 0.000020
# RL Epoch 29/200, Average Loss per Batch: 0.000023
# RL Epoch 30/200, Average Loss per Batch: 0.000023
# RL Epoch 31/200, Average Loss per Batch: 0.000025
# RL Epoch 32/200, Average Loss per Batch: 0.000027
# RL Epoch 33/200, Average Loss per Batch: 0.000028
# RL Epoch 34/200, Average Loss per Batch: 0.000028
# RL Epoch 35/200, Average Loss per Batch: 0.000028
# RL Epoch 36/200, Average Loss per Batch: 0.000026
# RL Epoch 37/200, Average Loss per Batch: 0.000026
# RL Epoch 38/200, Average Loss per Batch: 0.000025
# RL Epoch 39/200, Average Loss per Batch: 0.000025
# RL Epoch 40/200, Average Loss per Batch: 0.000022
# RL Epoch 41/200, Average Loss per Batch: 0.000022
# RL Epoch 42/200, Average Loss per Batch: 0.000021
# RL Epoch 43/200, Average Loss per Batch: 0.000021
# RL Epoch 44/200, Average Loss per Batch: 0.000020
# RL Epoch 45/200, Average Loss per Batch: 0.000021
# RL Epoch 46/200, Average Loss per Batch: 0.000019
# RL Epoch 47/200, Average Loss per Batch: 0.000020
# RL Epoch 48/200, Average Loss per Batch: 0.000021
# RL Epoch 49/200, Average Loss per Batch: 0.000021
# RL Epoch 50/200, Average Loss per Batch: 0.000020
# RL Epoch 51/200, Average Loss per Batch: 0.000022
# RL Epoch 52/200, Average Loss per Batch: 0.000019
# RL Epoch 53/200, Average Loss per Batch: 0.000019
# RL Epoch 54/200, Average Loss per Batch: 0.000021
# RL Epoch 55/200, Average Loss per Batch: 0.000019
# RL Epoch 56/200, Average Loss per Batch: 0.000018
# RL Epoch 57/200, Average Loss per Batch: 0.000022
# RL Epoch 58/200, Average Loss per Batch: 0.000020
# RL Epoch 59/200, Average Loss per Batch: 0.000021
# RL Epoch 60/200, Average Loss per Batch: 0.000026
# RL Epoch 61/200, Average Loss per Batch: 0.000025
# RL Epoch 62/200, Average Loss per Batch: 0.000022
# RL Epoch 63/200, Average Loss per Batch: 0.000024
# RL Epoch 64/200, Average Loss per Batch: 0.000021
# RL Epoch 65/200, Average Loss per Batch: 0.000020
# RL Epoch 66/200, Average Loss per Batch: 0.000021
# RL Epoch 67/200, Average Loss per Batch: 0.000020
# RL Epoch 68/200, Average Loss per Batch: 0.000018
# RL Epoch 69/200, Average Loss per Batch: 0.000017
# RL Epoch 70/200, Average Loss per Batch: 0.000018
# RL Epoch 71/200, Average Loss per Batch: 0.000019
# RL Epoch 72/200, Average Loss per Batch: 0.000019
# RL Epoch 73/200, Average Loss per Batch: 0.000022
# RL Epoch 74/200, Average Loss per Batch: 0.000021
# RL Epoch 75/200, Average Loss per Batch: 0.000020
# RL Epoch 76/200, Average Loss per Batch: 0.000024
# RL Epoch 77/200, Average Loss per Batch: 0.000023
# RL Epoch 78/200, Average Loss per Batch: 0.000021
# RL Epoch 79/200, Average Loss per Batch: 0.000030
# RL Epoch 80/200, Average Loss per Batch: 0.000024
# RL Epoch 81/200, Average Loss per Batch: 0.000027
# RL Epoch 82/200, Average Loss per Batch: 0.000036
# RL Epoch 83/200, Average Loss per Batch: 0.000037
# RL Epoch 84/200, Average Loss per Batch: 0.000036
# RL Epoch 85/200, Average Loss per Batch: 0.000036
# RL Epoch 86/200, Average Loss per Batch: 0.000037
# RL Epoch 87/200, Average Loss per Batch: 0.000035
# RL Epoch 88/200, Average Loss per Batch: 0.000030
# RL Epoch 89/200, Average Loss per Batch: 0.000032
# RL Epoch 90/200, Average Loss per Batch: 0.000026
# RL Epoch 91/200, Average Loss per Batch: 0.000020
# RL Epoch 92/200, Average Loss per Batch: 0.000017
# RL Epoch 93/200, Average Loss per Batch: 0.000017
# RL Epoch 94/200, Average Loss per Batch: 0.000015
# RL Epoch 95/200, Average Loss per Batch: 0.000014
# RL Epoch 96/200, Average Loss per Batch: 0.000013
# RL Epoch 97/200, Average Loss per Batch: 0.000013
# RL Epoch 98/200, Average Loss per Batch: 0.000012
# RL Epoch 99/200, Average Loss per Batch: 0.000012
# RL Epoch 100/200, Average Loss per Batch: 0.000013
# RL Epoch 101/200, Average Loss per Batch: 0.000012
# RL Epoch 102/200, Average Loss per Batch: 0.000013
# RL Epoch 103/200, Average Loss per Batch: 0.000013
# RL Epoch 104/200, Average Loss per Batch: 0.000014
# RL Epoch 105/200, Average Loss per Batch: 0.000014
# RL Epoch 106/200, Average Loss per Batch: 0.000014
# RL Epoch 107/200, Average Loss per Batch: 0.000014
# RL Epoch 108/200, Average Loss per Batch: 0.000014
# RL Epoch 109/200, Average Loss per Batch: 0.000015
# RL Epoch 110/200, Average Loss per Batch: 0.000016
# RL Epoch 111/200, Average Loss per Batch: 0.000018
# RL Epoch 112/200, Average Loss per Batch: 0.000021
# RL Epoch 113/200, Average Loss per Batch: 0.000024
# RL Epoch 114/200, Average Loss per Batch: 0.000026
# RL Epoch 115/200, Average Loss per Batch: 0.000034
# RL Epoch 116/200, Average Loss per Batch: 0.000036
# RL Epoch 117/200, Average Loss per Batch: 0.000039
# RL Epoch 118/200, Average Loss per Batch: 0.000045
# RL Epoch 119/200, Average Loss per Batch: 0.000039
# RL Epoch 120/200, Average Loss per Batch: 0.000032
# RL Epoch 121/200, Average Loss per Batch: 0.000030
# RL Epoch 122/200, Average Loss per Batch: 0.000030
# RL Epoch 123/200, Average Loss per Batch: 0.000028
# RL Epoch 124/200, Average Loss per Batch: 0.000023
# RL Epoch 125/200, Average Loss per Batch: 0.000024
# RL Epoch 126/200, Average Loss per Batch: 0.000019
# RL Epoch 127/200, Average Loss per Batch: 0.000017
# RL Epoch 128/200, Average Loss per Batch: 0.000017
# RL Epoch 129/200, Average Loss per Batch: 0.000016
# RL Epoch 130/200, Average Loss per Batch: 0.000015
# RL Epoch 131/200, Average Loss per Batch: 0.000016
# RL Epoch 132/200, Average Loss per Batch: 0.000016
# RL Epoch 133/200, Average Loss per Batch: 0.000016
# RL Epoch 134/200, Average Loss per Batch: 0.000017
# RL Epoch 135/200, Average Loss per Batch: 0.000018
# RL Epoch 136/200, Average Loss per Batch: 0.000017
# RL Epoch 137/200, Average Loss per Batch: 0.000018
# RL Epoch 138/200, Average Loss per Batch: 0.000019
# RL Epoch 139/200, Average Loss per Batch: 0.000018
# RL Epoch 140/200, Average Loss per Batch: 0.000018
# RL Epoch 141/200, Average Loss per Batch: 0.000020
# RL Epoch 142/200, Average Loss per Batch: 0.000018
# RL Epoch 143/200, Average Loss per Batch: 0.000018
# RL Epoch 144/200, Average Loss per Batch: 0.000020
# RL Epoch 145/200, Average Loss per Batch: 0.000020
# RL Epoch 146/200, Average Loss per Batch: 0.000020
# RL Epoch 147/200, Average Loss per Batch: 0.000020
# RL Epoch 148/200, Average Loss per Batch: 0.000018
# RL Epoch 149/200, Average Loss per Batch: 0.000016
# RL Epoch 150/200, Average Loss per Batch: 0.000016
# RL Epoch 151/200, Average Loss per Batch: 0.000017
# RL Epoch 152/200, Average Loss per Batch: 0.000015
# RL Epoch 153/200, Average Loss per Batch: 0.000015
# RL Epoch 154/200, Average Loss per Batch: 0.000017
# RL Epoch 155/200, Average Loss per Batch: 0.000015
# RL Epoch 156/200, Average Loss per Batch: 0.000016
# RL Epoch 157/200, Average Loss per Batch: 0.000023
# RL Epoch 158/200, Average Loss per Batch: 0.000020
# RL Epoch 159/200, Average Loss per Batch: 0.000021
# RL Epoch 160/200, Average Loss per Batch: 0.000033
# RL Epoch 161/200, Average Loss per Batch: 0.000029
# RL Epoch 162/200, Average Loss per Batch: 0.000029
# RL Epoch 163/200, Average Loss per Batch: 0.000050
# RL Epoch 164/200, Average Loss per Batch: 0.000045
# RL Epoch 165/200, Average Loss per Batch: 0.000045
# RL Epoch 166/200, Average Loss per Batch: 0.000050
# RL Epoch 167/200, Average Loss per Batch: 0.000047
# RL Epoch 168/200, Average Loss per Batch: 0.000041
# RL Epoch 169/200, Average Loss per Batch: 0.000030
# RL Epoch 170/200, Average Loss per Batch: 0.000029
# RL Epoch 171/200, Average Loss per Batch: 0.000021
# RL Epoch 172/200, Average Loss per Batch: 0.000017
# RL Epoch 173/200, Average Loss per Batch: 0.000015
# RL Epoch 174/200, Average Loss per Batch: 0.000014
# RL Epoch 175/200, Average Loss per Batch: 0.000012
# RL Epoch 176/200, Average Loss per Batch: 0.000012
# RL Epoch 177/200, Average Loss per Batch: 0.000011
# RL Epoch 178/200, Average Loss per Batch: 0.000011
# RL Epoch 179/200, Average Loss per Batch: 0.000011
# RL Epoch 180/200, Average Loss per Batch: 0.000011
# RL Epoch 181/200, Average Loss per Batch: 0.000011
# RL Epoch 182/200, Average Loss per Batch: 0.000012
# RL Epoch 183/200, Average Loss per Batch: 0.000012
# RL Epoch 184/200, Average Loss per Batch: 0.000012
# RL Epoch 185/200, Average Loss per Batch: 0.000013
# RL Epoch 186/200, Average Loss per Batch: 0.000013
# RL Epoch 187/200, Average Loss per Batch: 0.000015
# RL Epoch 188/200, Average Loss per Batch: 0.000016
# RL Epoch 189/200, Average Loss per Batch: 0.000018
# RL Epoch 190/200, Average Loss per Batch: 0.000017
# RL Epoch 191/200, Average Loss per Batch: 0.000018
# RL Epoch 192/200, Average Loss per Batch: 0.000017
# RL Epoch 193/200, Average Loss per Batch: 0.000016
# RL Epoch 194/200, Average Loss per Batch: 0.000016
# RL Epoch 195/200, Average Loss per Batch: 0.000016
# RL Epoch 196/200, Average Loss per Batch: 0.000019
# RL Epoch 197/200, Average Loss per Batch: 0.000022
# RL Epoch 198/200, Average Loss per Batch: 0.000027
# RL Epoch 199/200, Average Loss per Batch: 0.000029
# RL Epoch 200/200, Average Loss per Batch: 0.000033
# --- RL Fine-Tuning Complete ---
#
#  Training Set Performance Metrics (LSTM):
#  Mean Absolute Error (MAE) : ₹5.85
#  Mean Squared Error (MSE)  : ₹60.07
#  Root Squared Error (RMSE) : ₹7.75
#  R² Score                  : 0.9984
#  Mean Absolute Percentage Error (MAPE) : 0.44%
#  Accuracy (100 - MAPE) : 99.56%
#  MSE Percentage of Average Price : 4.32%
#  MAE Percentage of Average Price : 0.42%
#
#  Validation Set Performance Metrics (LSTM):
#  Mean Absolute Error (MAE) : ₹208.35
#  Mean Squared Error (MSE)  : ₹61692.62
#  Root Squared Error (RMSE) : ₹248.38
#  R² Score                  : -1.4647
#  Mean Absolute Percentage Error (MAPE) : 11.74%
#  Accuracy (100 - MAPE) : 88.26%
#  MSE Percentage of Average Price: 3543.13%
#  MAE Percentage of Average Price: 11.97%
#
#  Prediction for 2025-06-18:
#  Predicted Closing Price: ₹1585.36
#  Actual Closing Price   : ₹1632.9000244140625
#  Test Set Performance Metrics (LSTM):
#  Mean Absolute Error (MAE) : ₹33.93
#  Mean Squared Error (MSE)  : ₹1564.65
#  Root Squared Error (RMSE) : ₹39.56
#  R² Score                  : -0.8351
#  Mean Absolute Percentage Error (MAPE) : 2.12%
#  Accuracy (100 - MAPE) : 97.88%
#  MSE Percentage of Average Price: 98.02%
#  MAE Percentage of Average Price: 2.13%
