# %% [markdown]
# # **150 episodes**

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import SimpleRNN
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
from matplotlib.dates import DateFormatter
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
import numpy as np
import pandas as pd
import datetime
import holidays
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import warnings

warnings.filterwarnings('ignore')

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

SYMBOL = "INFY.NS"
SEQUENCE_LENGTH = 60

TRAIN_START_DATE = "2020-06-01"
TRAIN_END_DATE = "2025-05-31"

TEST_START_DATE = "2025-06-01"
TEST_END_DATE = "2025-07-01"

# Get Indian trading holidays
def get_nse_holidays():
    in_holidays = holidays.India(years=range(2020, 2026))
    return set(in_holidays.keys())

TRADING_HOLIDAYS = get_nse_holidays()

def is_valid_date(date_str):
    try:
        date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()
        if not (datetime.date(2025, 6, 1) <= date <= datetime.date(2025, 7, 1)):
            print("Date must be between 2025-06-01 and 2025-07-01.")
            return False
        if date.weekday() >= 5:
            print("Weekends are not trading days.")
            return False
        if date in TRADING_HOLIDAYS:
            print("Entered date is a trading holiday.")
            return False
        return True
    except ValueError:
        print("Invalid date format. Use YYYY-MM-DD.")
        return False

def get_stock_data():
    print("Fetching data from Yahoo Finance...")
    full_df = yf.download(SYMBOL, start=TRAIN_START_DATE, end=TEST_END_DATE)
    full_df = full_df[['Close']]
    full_df.dropna(inplace=True)
    full_df.index = pd.to_datetime(full_df.index)

    train_df = full_df.loc[TRAIN_START_DATE:TRAIN_END_DATE]
    test_df = full_df.loc[TEST_START_DATE:TEST_END_DATE]
    return train_df, test_df, full_df

# Prompt until valid date is entered
def get_user_date():
    while True:
        date_input = input("Enter a date (YYYY-MM-DD): ")
        if is_valid_date(date_input):
            return datetime.datetime.strptime(date_input, "%Y-%m-%d").date()

# Build the SimpleRNN model
def build_model(input_shape, learning_rate=0.001): # Added learning_rate parameter
    model = Sequential()
    model.add(SimpleRNN(units=50, activation='tanh', input_shape=input_shape))
    model.add(Dense(1))
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate) # Use custom learning rate
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# Reinforcement Learning Fine-Tuning
class RLAgent:
    """
    A simple RL Agent to fine-tune the RNN model.
    The "environment" is the time series data, and the "action" is the prediction.
    The reward is based on prediction accuracy.
    """
    def __init__(self, model, learning_rate=0.001):
        self.model = model
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate) # Pass learning_rate to RLAgent

    @tf.function
    def train_step(self, state, target):
        """
        Performs a single training step to fine-tune the model weights.
        """
        with tf.GradientTape() as tape:
            prediction = self.model(state, training=True)
            # Use Mean Squared Error directly as the loss to minimize
            loss = tf.reduce_mean(tf.square(tf.cast(target, tf.float32) - prediction))

        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))
        return loss # Return the mean loss for the batch


def fine_tune_with_rl(model, X_train, y_train, epochs=5, learning_rate=0.001, batch_size=32):
    """
    Fine- tunes the pre-trained RNN model using a simple reinforcement learning loop with batched data.
    """
    print("\n--- Starting Reinforcement Learning Fine-Tuning (Batched) ---")
    agent = RLAgent(model, learning_rate=learning_rate)

    # Create a TensorFlow Dataset and batch it
    dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
    dataset = dataset.batch(batch_size)

    num_batches = tf.data.experimental.cardinality(dataset).numpy()

    for epoch in range(epochs):
        total_loss = 0
        batch_count = 0
        for batch_x, batch_y in dataset:
            # Ensure batch_x has the correct shape (batch_size, sequence_length, 1)
            batch_x_reshaped = tf.reshape(batch_x, (tf.shape(batch_x)[0], tf.shape(batch_x)[1], 1))
            loss = agent.train_step(batch_x_reshaped, batch_y)
            total_loss += loss.numpy() # Sum up the mean loss for each batch
            batch_count += 1

        # Calculate average loss per epoch
        average_epoch_loss = total_loss / num_batches if num_batches > 0 else 0
        print(f"RL Epoch {epoch + 1}/{epochs}, Average Loss per Batch: {average_epoch_loss:.6f}") # Print average loss

    print("--- RL Fine-Tuning Complete ---")
    return model


def create_test_sequences(train_df, test_df, scaler):
    combined = pd.concat([train_df, test_df])
    scaled = scaler.transform(combined[['Close']])
    X_test = []
    test_dates = test_df.index.date

    for i in range(len(train_df), len(combined)):
        if i - SEQUENCE_LENGTH < 0:
            continue
        seq = scaled[i - SEQUENCE_LENGTH:i]
        X_test.append(seq)

    X_test = np.array(X_test)
    return X_test, test_dates

def predict_price_on_test(model, full_df, scaler, user_date):
    all_dates = full_df.index.date
    try:
        idx = list(all_dates).index(user_date)
    except ValueError:
        print("User date not found in data.")
        return None, None, user_date

    if idx < SEQUENCE_LENGTH:
        print("Not enough data to predict for this date.")
        return None, None, user_date

    input_seq = scaler.transform(full_df[['Close']].values)[idx - SEQUENCE_LENGTH:idx]
    input_seq = np.reshape(input_seq, (1, SEQUENCE_LENGTH, 1))

    predicted_scaled = model.predict(input_seq, verbose=0)
    predicted_price = scaler.inverse_transform(predicted_scaled)[0][0]

    actual_price = float(full_df.iloc[idx]['Close']) if idx < len(full_df) else None
    return predicted_price, actual_price, full_df.index[idx].date()

# Plot the result
def plot_results(df, predicted_date, predicted_price, actual_price):
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['Close'], label='Historical Close Price',zorder=1)
    #plt.axvline(pd.to_datetime(predicted_date), color='red', linestyle='--', label='Predicted Date')
    plt.scatter(pd.to_datetime(predicted_date), predicted_price, color='orange', label='Predicted Price',zorder=2)
    if actual_price is not None:
        plt.scatter(pd.to_datetime(predicted_date), actual_price, color='green', label='Actual Price',zorder=3, s=100)
    plt.title("INFOSYS Stock Price with Prediction (yfinance)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

#Plotting error with no. of epochs
def plot_training_loss(history):
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title("Training and Validation Loss Over Epochs (RNN)")
    plt.xlabel("Epoch no.")
    plt.ylabel("Loss (MSE)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def main():
    print("=== INFOSYS LSTM Stock Price Predictor (Test Phase June–July 2025) ===")
    user_date = get_user_date()

    # Step 1: Get stock data
    train_df, test_df, full_df = get_stock_data()

    # Step 2: Preprocess
    scaler = MinMaxScaler()
    scaled_train = scaler.fit_transform(train_df[['Close']])
    X, y = [], []
    for i in range(SEQUENCE_LENGTH, len(scaled_train)):
        X.append(scaled_train[i - SEQUENCE_LENGTH:i])
        y.append(scaled_train[i])
    X = np.array(X)
    y = np.array(y)

    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)
    #early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
    # Step 3: Build and train model
    model = build_model((X_train.shape[1], 1), learning_rate=0.0005) # Reduced Adam learning rate
    print("Training RNN model...")
    history = model.fit(X_train, y_train, epochs=10000, batch_size=64, validation_data=(X_val, y_val), verbose = 1) #callbacks = [early_stop], verbose=1)

    #print(f"\nBest weights restored from epoch: {early_stop.best_epoch + 1}")

    # Step 4: Plot training loss
    plot_training_loss(history)

    # Step 5: Fine-tune with Reinforcement Learning
    rl_tuned_model = fine_tune_with_rl(model, X_train, y_train, epochs=150, learning_rate=0.0001, batch_size=32)

    # Predict on training data to evaluate performance
    y_train_pred_scaled = rl_tuned_model.predict(X_train, verbose=0)
    y_train_pred = scaler.inverse_transform(y_train_pred_scaled)
    y_true_train = scaler.inverse_transform(y_train.reshape(-1, 1))

    # Calculate and print training metrics
    mae_train = mean_absolute_error(y_true_train, y_train_pred)
    mse_train = mean_squared_error(y_true_train, y_train_pred)
    rmse_train = np.sqrt(mse_train)
    r2_train = r2_score(y_true_train, y_train_pred)
    mape_train = mean_absolute_percentage_error(y_true_train, y_train_pred) * 100
    accuracy_train = 100 - mape_train
    mse_percent_train = (mse_train / np.mean(y_true_train)) * 100 if np.mean(y_true_train) != 0 else np.nan
    mae_percent_train = (mae_train / np.mean(y_true_train)) * 100 if np.mean(y_true_train) != 0 else np.nan
    print("\n Training Set Performance Metrics (RNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_train:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_train:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_train:.2f}")
    print(f" R² Score                  : {r2_train:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_train:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_train:.2f}%")
    print(f" MSE Percentage of Average Price : {mse_percent_train:.2f}%")
    print(f" MAE Percentage of Average Price : {mae_percent_train:.2f}%")

    # Predict on validation set
    y_val_pred_scaled = rl_tuned_model.predict(X_val, verbose=0)
    y_val_pred = scaler.inverse_transform(y_val_pred_scaled)
    y_val_true = scaler.inverse_transform(y_val.reshape(-1, 1))

    # Calculate and print validation metrics
    mae_val = mean_absolute_error(y_val_true, y_val_pred)
    mse_val = mean_squared_error(y_val_true, y_val_pred)
    rmse_val = np.sqrt(mse_val)
    r2_val = r2_score(y_val_true, y_val_pred)
    mape_val = mean_absolute_percentage_error(y_val_true, y_val_pred) * 100
    accuracy_val = 100 - mape_val
    mse_percent_val = (mse_val / np.mean(y_val_true)) * 100 if np.mean(y_val_true) != 0 else np.nan
    mae_percent_val = (mae_val / np.mean(y_val_true)) * 100 if np.mean(y_val_true) != 0 else np.nan
    print("\n Validation Set Performance Metrics (RNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_val:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_val:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_val:.2f}")
    print(f" R² Score                  : {r2_val:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_val:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_val:.2f}%")
    print(f" MSE Percentage of Average Price: {mse_percent_val:.2f}%")
    print(f" MAE Percentage of Average Price: {mae_percent_val:.2f}%")


    # Step 6: Predict for user-input test date
    predicted_price, actual_price, predicted_date = predict_price_on_test(rl_tuned_model, full_df, scaler, user_date)
    if predicted_price is not None:
        print(f"\n Prediction for {predicted_date}:")
        print(f" Predicted Closing Price: ₹{predicted_price:.2f}")
        if actual_price is not None:
            print(f" Actual Closing Price   : ₹{actual_price}")
        else:
            print("Actual price not available.")

        plot_results(full_df, predicted_date, predicted_price, actual_price)
    else:
        print("❌ Unable to make prediction.")

    # === Step 7: Predict all test dates and compare ===

    # Reuse combined full_df
    combined_df = pd.concat([train_df, test_df])
    scaled_combined = scaler.transform(combined_df[['Close']])

    X_test_all = []
    test_date_indexes = []

    for i in range(len(train_df), len(combined_df)):
        if i - SEQUENCE_LENGTH < 0:
            continue
        seq = scaled_combined[i - SEQUENCE_LENGTH:i]
        X_test_all.append(seq)
        test_date_indexes.append(combined_df.index[i])

    X_test_all = np.array(X_test_all)

    # Predict on test sequences
    y_test_pred_scaled = rl_tuned_model.predict(X_test_all, verbose=0)
    y_test_pred = scaler.inverse_transform(y_test_pred_scaled)

    # Actual prices
    y_test_true = test_df.loc[test_date_indexes, 'Close'].values

    # Calculate and print test metrics
    mae_test = mean_absolute_error(y_test_true, y_test_pred)
    mse_test = mean_squared_error(y_test_true, y_test_pred)
    rmse_test = np.sqrt(mse_test)
    r2_test = r2_score(y_test_true, y_test_pred)
    mape_test = mean_absolute_percentage_error(y_test_true, y_test_pred) * 100
    accuracy_test = 100 - mape_test
    mse_percent_test = (mse_test / np.mean(y_test_true)) * 100 if np.mean(y_test_true) != 0 else np.nan
    mae_percent_test = (mae_test / np.mean(y_test_true)) * 100 if np.mean(y_test_true) != 0 else np.nan
    print("\n Test Set Performance Metrics (RNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_test:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_test:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_test:.2f}")
    print(f" R² Score                  : {r2_test:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_test:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_test:.2f}%")
    print(f" MSE Percentage of Average Price: {mse_percent_test:.2f}%")
    print(f" MAE Percentage of Average Price: {mae_percent_test:.2f}%")

    # Plot actual vs predicted
    plt.figure(figsize=(12, 6))
    plt.plot(test_date_indexes, y_test_true, label='Actual Price')
    plt.plot(test_date_indexes, y_test_pred, label='Predicted Price')
    plt.title("Actual vs Predicted INFY Closing Prices (01-Jun to 01-Jul 2025)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.xticks(rotation=45)
    plt.gca().xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# === INFOSYS LSTM Stock Price Predictor (Test Phase June–July 2025) ===
# Fetching data from Yahoo Finance...
# [*********************100%***********************]  1 of 1 completed
# Streaming output truncated to the last 5000 lines.
# Epoch 7501/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.2981e-05 - val_loss: 0.0013
# Epoch 7502/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0165e-05 - val_loss: 0.0015
# Epoch 7503/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.8647e-05 - val_loss: 0.0015
# Epoch 7504/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8512e-05 - val_loss: 0.0014
# Epoch 7505/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6229e-05 - val_loss: 0.0015
# Epoch 7506/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0909e-05 - val_loss: 0.0015
# Epoch 7507/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7323e-05 - val_loss: 0.0015
# Epoch 7508/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.0403e-05 - val_loss: 0.0015
# Epoch 7509/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.1145e-05 - val_loss: 0.0014
# Epoch 7510/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.0175e-05 - val_loss: 0.0012
# Epoch 7511/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.7228e-05 - val_loss: 0.0012
# Epoch 7512/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7012e-05 - val_loss: 0.0011
# Epoch 7513/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8679e-05 - val_loss: 0.0012
# Epoch 7514/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6242e-05 - val_loss: 0.0013
# Epoch 7515/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8089e-05 - val_loss: 0.0013
# Epoch 7516/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1524e-05 - val_loss: 0.0014
# Epoch 7517/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.4196e-05 - val_loss: 0.0014
# Epoch 7518/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.4787e-05 - val_loss: 0.0014
# Epoch 7519/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.5930e-05 - val_loss: 0.0013
# Epoch 7520/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7339e-05 - val_loss: 0.0012
# Epoch 7521/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.1451e-05 - val_loss: 0.0011
# Epoch 7522/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.8547e-05 - val_loss: 0.0010
# Epoch 7523/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 4.0947e-05 - val_loss: 0.0012
# Epoch 7524/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.0197e-05 - val_loss: 0.0013
# Epoch 7525/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.8150e-05 - val_loss: 0.0013
# Epoch 7526/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.3705e-05 - val_loss: 0.0012
# Epoch 7527/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.3122e-05 - val_loss: 0.0012
# Epoch 7528/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.6887e-05 - val_loss: 0.0011
# Epoch 7529/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.9016e-05 - val_loss: 0.0012
# Epoch 7530/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0871e-05 - val_loss: 0.0012
# Epoch 7531/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.1830e-05 - val_loss: 0.0012
# Epoch 7532/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.3924e-05 - val_loss: 0.0012
# Epoch 7533/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.6351e-05 - val_loss: 0.0012
# Epoch 7534/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7128e-05 - val_loss: 0.0012
# Epoch 7535/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.4726e-05 - val_loss: 0.0013
# Epoch 7536/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.5671e-05 - val_loss: 0.0014
# Epoch 7537/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.7849e-05 - val_loss: 0.0014
# Epoch 7538/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.6776e-05 - val_loss: 0.0014
# Epoch 7539/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.3664e-05 - val_loss: 0.0014
# Epoch 7540/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.2614e-05 - val_loss: 0.0015
# Epoch 7541/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.9432e-05 - val_loss: 0.0015
# Epoch 7542/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6161e-05 - val_loss: 0.0014
# Epoch 7543/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3617e-05 - val_loss: 0.0013
# Epoch 7544/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0073e-05 - val_loss: 0.0014
# Epoch 7545/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8024e-05 - val_loss: 0.0014
# Epoch 7546/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8149e-05 - val_loss: 0.0014
# Epoch 7547/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0594e-05 - val_loss: 0.0014
# Epoch 7548/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.2745e-05 - val_loss: 0.0014
# Epoch 7549/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3124e-05 - val_loss: 0.0015
# Epoch 7550/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2259e-05 - val_loss: 0.0015
# Epoch 7551/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1043e-05 - val_loss: 0.0016
# Epoch 7552/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0111e-05 - val_loss: 0.0016
# Epoch 7553/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.9244e-05 - val_loss: 0.0016
# Epoch 7554/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.8397e-05 - val_loss: 0.0016
# Epoch 7555/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7733e-05 - val_loss: 0.0016
# Epoch 7556/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7435e-05 - val_loss: 0.0016
# Epoch 7557/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.7351e-05 - val_loss: 0.0016
# Epoch 7558/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6713e-05 - val_loss: 0.0016
# Epoch 7559/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6369e-05 - val_loss: 0.0015
# Epoch 7560/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7619e-05 - val_loss: 0.0015
# Epoch 7561/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.0363e-05 - val_loss: 0.0014
# Epoch 7562/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2598e-05 - val_loss: 0.0013
# Epoch 7563/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2789e-05 - val_loss: 0.0013
# Epoch 7564/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0589e-05 - val_loss: 0.0013
# Epoch 7565/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8107e-05 - val_loss: 0.0014
# Epoch 7566/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8301e-05 - val_loss: 0.0014
# Epoch 7567/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.9284e-05 - val_loss: 0.0015
# Epoch 7568/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.7192e-05 - val_loss: 0.0014
# Epoch 7569/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.5112e-05 - val_loss: 0.0014
# Epoch 7570/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5557e-05 - val_loss: 0.0013
# Epoch 7571/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6369e-05 - val_loss: 0.0013
# Epoch 7572/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5517e-05 - val_loss: 0.0013
# Epoch 7573/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.4882e-05 - val_loss: 0.0013
# Epoch 7574/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5574e-05 - val_loss: 0.0013
# Epoch 7575/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.4855e-05 - val_loss: 0.0013
# Epoch 7576/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.4137e-05 - val_loss: 0.0013
# Epoch 7577/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5453e-05 - val_loss: 0.0013
# Epoch 7578/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9401e-05 - val_loss: 0.0013
# Epoch 7579/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0991e-05 - val_loss: 0.0013
# Epoch 7580/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9405e-05 - val_loss: 0.0013
# Epoch 7581/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9453e-05 - val_loss: 0.0013
# Epoch 7582/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0854e-05 - val_loss: 0.0013
# Epoch 7583/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1334e-05 - val_loss: 0.0012
# Epoch 7584/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0865e-05 - val_loss: 0.0012
# Epoch 7585/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9775e-05 - val_loss: 0.0012
# Epoch 7586/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0185e-05 - val_loss: 0.0012
# Epoch 7587/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2024e-05 - val_loss: 0.0012
# Epoch 7588/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.3526e-05 - val_loss: 0.0012
# Epoch 7589/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5093e-05 - val_loss: 0.0012
# Epoch 7590/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5283e-05 - val_loss: 0.0012
# Epoch 7591/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7091e-05 - val_loss: 0.0012
# Epoch 7592/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.9319e-05 - val_loss: 0.0013
# Epoch 7593/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9821e-05 - val_loss: 0.0012
# Epoch 7594/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.7998e-05 - val_loss: 0.0012
# Epoch 7595/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5285e-05 - val_loss: 0.0012
# Epoch 7596/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1981e-05 - val_loss: 0.0013
# Epoch 7597/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1476e-05 - val_loss: 0.0014
# Epoch 7598/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4682e-05 - val_loss: 0.0013
# Epoch 7599/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6658e-05 - val_loss: 0.0013
# Epoch 7600/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9034e-05 - val_loss: 0.0012
# Epoch 7601/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8693e-05 - val_loss: 0.0013
# Epoch 7602/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7522e-05 - val_loss: 0.0014
# Epoch 7603/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.7497e-05 - val_loss: 0.0015
# Epoch 7604/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.9284e-05 - val_loss: 0.0015
# Epoch 7605/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8102e-05 - val_loss: 0.0015
# Epoch 7606/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1376e-05 - val_loss: 0.0014
# Epoch 7607/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.6870e-05 - val_loss: 0.0014
# Epoch 7608/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.2158e-05 - val_loss: 0.0013
# Epoch 7609/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.2399e-05 - val_loss: 0.0013
# Epoch 7610/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.4034e-05 - val_loss: 0.0012
# Epoch 7611/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.3762e-05 - val_loss: 0.0011
# Epoch 7612/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.0874e-05 - val_loss: 0.0011
# Epoch 7613/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.6260e-05 - val_loss: 0.0013
# Epoch 7614/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.5735e-05 - val_loss: 0.0014
# Epoch 7615/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5037e-05 - val_loss: 0.0015
# Epoch 7616/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.4642e-05 - val_loss: 0.0013
# Epoch 7617/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2021e-05 - val_loss: 0.0013
# Epoch 7618/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8038e-05 - val_loss: 0.0013
# Epoch 7619/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6124e-05 - val_loss: 0.0013
# Epoch 7620/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.4648e-05 - val_loss: 0.0013
# Epoch 7621/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.4523e-05 - val_loss: 0.0013
# Epoch 7622/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5811e-05 - val_loss: 0.0013
# Epoch 7623/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8111e-05 - val_loss: 0.0014
# Epoch 7624/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.8684e-05 - val_loss: 0.0014
# Epoch 7625/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8369e-05 - val_loss: 0.0014
# Epoch 7626/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7251e-05 - val_loss: 0.0013
# Epoch 7627/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7759e-05 - val_loss: 0.0013
# Epoch 7628/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8873e-05 - val_loss: 0.0013
# Epoch 7629/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9593e-05 - val_loss: 0.0014
# Epoch 7630/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0925e-05 - val_loss: 0.0014
# Epoch 7631/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3339e-05 - val_loss: 0.0014
# Epoch 7632/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.5974e-05 - val_loss: 0.0014
# Epoch 7633/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6228e-05 - val_loss: 0.0013
# Epoch 7634/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.3641e-05 - val_loss: 0.0013
# Epoch 7635/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1424e-05 - val_loss: 0.0013
# Epoch 7636/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1456e-05 - val_loss: 0.0013
# Epoch 7637/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.2667e-05 - val_loss: 0.0013
# Epoch 7638/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2185e-05 - val_loss: 0.0012
# Epoch 7639/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5189e-05 - val_loss: 0.0012
# Epoch 7640/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1584e-05 - val_loss: 0.0012
# Epoch 7641/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1579e-05 - val_loss: 0.0012
# Epoch 7642/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8625e-05 - val_loss: 0.0012
# Epoch 7643/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6617e-05 - val_loss: 0.0012
# Epoch 7644/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8663e-05 - val_loss: 0.0012
# Epoch 7645/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0831e-05 - val_loss: 0.0012
# Epoch 7646/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.5550e-05 - val_loss: 0.0013
# Epoch 7647/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.8320e-05 - val_loss: 0.0014
# Epoch 7648/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.5345e-05 - val_loss: 0.0013
# Epoch 7649/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.6208e-05 - val_loss: 0.0013
# Epoch 7650/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4939e-05 - val_loss: 0.0013
# Epoch 7651/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.3569e-05 - val_loss: 0.0013
# Epoch 7652/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.1696e-05 - val_loss: 0.0013
# Epoch 7653/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.5341e-05 - val_loss: 0.0013
# Epoch 7654/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.5910e-05 - val_loss: 0.0013
# Epoch 7655/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1897e-05 - val_loss: 0.0014
# Epoch 7656/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8176e-05 - val_loss: 0.0014
# Epoch 7657/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4811e-05 - val_loss: 0.0013
# Epoch 7658/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.4279e-05 - val_loss: 0.0013
# Epoch 7659/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1754e-05 - val_loss: 0.0013
# Epoch 7660/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9820e-05 - val_loss: 0.0013
# Epoch 7661/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2639e-05 - val_loss: 0.0013
# Epoch 7662/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5876e-05 - val_loss: 0.0014
# Epoch 7663/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.5966e-05 - val_loss: 0.0015
# Epoch 7664/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6381e-05 - val_loss: 0.0015
# Epoch 7665/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.7229e-05 - val_loss: 0.0015
# Epoch 7666/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6580e-05 - val_loss: 0.0015
# Epoch 7667/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.4356e-05 - val_loss: 0.0015
# Epoch 7668/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2514e-05 - val_loss: 0.0015
# Epoch 7669/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1206e-05 - val_loss: 0.0016
# Epoch 7670/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1049e-05 - val_loss: 0.0016
# Epoch 7671/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0874e-05 - val_loss: 0.0016
# Epoch 7672/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0539e-05 - val_loss: 0.0016
# Epoch 7673/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9767e-05 - val_loss: 0.0015
# Epoch 7674/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9292e-05 - val_loss: 0.0014
# Epoch 7675/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9164e-05 - val_loss: 0.0013
# Epoch 7676/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9590e-05 - val_loss: 0.0013
# Epoch 7677/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0453e-05 - val_loss: 0.0014
# Epoch 7678/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0557e-05 - val_loss: 0.0014
# Epoch 7679/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7674e-05 - val_loss: 0.0015
# Epoch 7680/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5063e-05 - val_loss: 0.0014
# Epoch 7681/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.4134e-05 - val_loss: 0.0014
# Epoch 7682/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.4133e-05 - val_loss: 0.0014
# Epoch 7683/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3855e-05 - val_loss: 0.0014
# Epoch 7684/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3480e-05 - val_loss: 0.0015
# Epoch 7685/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.2451e-05 - val_loss: 0.0015
# Epoch 7686/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0908e-05 - val_loss: 0.0014
# Epoch 7687/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.5153e-06 - val_loss: 0.0014
# Epoch 7688/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.8095e-06 - val_loss: 0.0015
# Epoch 7689/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.2610e-06 - val_loss: 0.0015
# Epoch 7690/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0581e-05 - val_loss: 0.0015
# Epoch 7691/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1446e-05 - val_loss: 0.0014
# Epoch 7692/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1012e-05 - val_loss: 0.0014
# Epoch 7693/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.0470e-05 - val_loss: 0.0014
# Epoch 7694/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0612e-05 - val_loss: 0.0013
# Epoch 7695/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0945e-05 - val_loss: 0.0013
# Epoch 7696/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1015e-05 - val_loss: 0.0013
# Epoch 7697/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1250e-05 - val_loss: 0.0013
# Epoch 7698/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1893e-05 - val_loss: 0.0013
# Epoch 7699/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2960e-05 - val_loss: 0.0014
# Epoch 7700/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.4244e-05 - val_loss: 0.0014
# Epoch 7701/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5651e-05 - val_loss: 0.0014
# Epoch 7702/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7205e-05 - val_loss: 0.0014
# Epoch 7703/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9122e-05 - val_loss: 0.0013
# Epoch 7704/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1251e-05 - val_loss: 0.0013
# Epoch 7705/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2764e-05 - val_loss: 0.0013
# Epoch 7706/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5130e-05 - val_loss: 0.0014
# Epoch 7707/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9634e-05 - val_loss: 0.0015
# Epoch 7708/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.0940e-05 - val_loss: 0.0015
# Epoch 7709/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1325e-05 - val_loss: 0.0014
# Epoch 7710/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.6920e-05 - val_loss: 0.0013
# Epoch 7711/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.0090e-05 - val_loss: 0.0013
# Epoch 7712/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.6651e-05 - val_loss: 0.0013
# Epoch 7713/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.4928e-05 - val_loss: 0.0014
# Epoch 7714/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.0557e-05 - val_loss: 0.0012
# Epoch 7715/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.7248e-05 - val_loss: 0.0012
# Epoch 7716/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.3226e-05 - val_loss: 0.0012
# Epoch 7717/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.2747e-05 - val_loss: 0.0012
# Epoch 7718/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6677e-05 - val_loss: 0.0013
# Epoch 7719/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3775e-05 - val_loss: 0.0012
# Epoch 7720/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.2160e-05 - val_loss: 0.0012
# Epoch 7721/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5100e-05 - val_loss: 0.0013
# Epoch 7722/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8124e-05 - val_loss: 0.0013
# Epoch 7723/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8268e-05 - val_loss: 0.0014
# Epoch 7724/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8504e-05 - val_loss: 0.0012
# Epoch 7725/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.6297e-05 - val_loss: 0.0012
# Epoch 7726/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.1630e-05 - val_loss: 0.0012
# Epoch 7727/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.5361e-05 - val_loss: 0.0011
# Epoch 7728/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.6946e-05 - val_loss: 0.0011
# Epoch 7729/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.1355e-05 - val_loss: 0.0011
# Epoch 7730/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.5940e-05 - val_loss: 9.3410e-04
# Epoch 7731/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.7715e-05 - val_loss: 9.9821e-04
# Epoch 7732/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.4231e-05 - val_loss: 0.0012
# Epoch 7733/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.7629e-05 - val_loss: 0.0013
# Epoch 7734/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.2136e-05 - val_loss: 0.0015
# Epoch 7735/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.6901e-05 - val_loss: 0.0013
# Epoch 7736/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.1319e-05 - val_loss: 0.0013
# Epoch 7737/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.1908e-05 - val_loss: 0.0012
# Epoch 7738/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8463e-05 - val_loss: 0.0012
# Epoch 7739/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.5708e-05 - val_loss: 0.0013
# Epoch 7740/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.3780e-05 - val_loss: 0.0013
# Epoch 7741/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.2985e-05 - val_loss: 0.0013
# Epoch 7742/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.3741e-05 - val_loss: 0.0013
# Epoch 7743/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.3409e-05 - val_loss: 0.0013
# Epoch 7744/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1977e-05 - val_loss: 0.0013
# Epoch 7745/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1338e-05 - val_loss: 0.0014
# Epoch 7746/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0738e-05 - val_loss: 0.0014
# Epoch 7747/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0774e-05 - val_loss: 0.0014
# Epoch 7748/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1637e-05 - val_loss: 0.0014
# Epoch 7749/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2804e-05 - val_loss: 0.0015
# Epoch 7750/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.3674e-05 - val_loss: 0.0015
# Epoch 7751/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.4457e-05 - val_loss: 0.0015
# Epoch 7752/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.4973e-05 - val_loss: 0.0016
# Epoch 7753/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5204e-05 - val_loss: 0.0016
# Epoch 7754/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5339e-05 - val_loss: 0.0016
# Epoch 7755/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5206e-05 - val_loss: 0.0016
# Epoch 7756/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4825e-05 - val_loss: 0.0016
# Epoch 7757/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4314e-05 - val_loss: 0.0015
# Epoch 7758/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3845e-05 - val_loss: 0.0015
# Epoch 7759/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3822e-05 - val_loss: 0.0015
# Epoch 7760/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4634e-05 - val_loss: 0.0015
# Epoch 7761/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6281e-05 - val_loss: 0.0014
# Epoch 7762/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8282e-05 - val_loss: 0.0014
# Epoch 7763/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0153e-05 - val_loss: 0.0014
# Epoch 7764/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1111e-05 - val_loss: 0.0014
# Epoch 7765/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0975e-05 - val_loss: 0.0014
# Epoch 7766/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1572e-05 - val_loss: 0.0014
# Epoch 7767/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3082e-05 - val_loss: 0.0014
# Epoch 7768/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.3587e-05 - val_loss: 0.0013
# Epoch 7769/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3436e-05 - val_loss: 0.0014
# Epoch 7770/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5882e-05 - val_loss: 0.0014
# Epoch 7771/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.2210e-05 - val_loss: 0.0014
# Epoch 7772/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.6749e-05 - val_loss: 0.0014
# Epoch 7773/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.4998e-05 - val_loss: 0.0014
# Epoch 7774/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.5125e-05 - val_loss: 0.0013
# Epoch 7775/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.6159e-05 - val_loss: 0.0014
# Epoch 7776/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.0717e-05 - val_loss: 0.0014
# Epoch 7777/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.4384e-05 - val_loss: 0.0015
# Epoch 7778/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.2852e-05 - val_loss: 0.0015
# Epoch 7779/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.2050e-05 - val_loss: 0.0014
# Epoch 7780/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8386e-05 - val_loss: 0.0013
# Epoch 7781/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5659e-05 - val_loss: 0.0014
# Epoch 7782/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5535e-05 - val_loss: 0.0014
# Epoch 7783/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7023e-05 - val_loss: 0.0014
# Epoch 7784/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7266e-05 - val_loss: 0.0015
# Epoch 7785/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7754e-05 - val_loss: 0.0015
# Epoch 7786/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9346e-05 - val_loss: 0.0016
# Epoch 7787/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8960e-05 - val_loss: 0.0015
# Epoch 7788/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7595e-05 - val_loss: 0.0014
# Epoch 7789/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8629e-05 - val_loss: 0.0013
# Epoch 7790/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1135e-05 - val_loss: 0.0013
# Epoch 7791/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1684e-05 - val_loss: 0.0014
# Epoch 7792/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9996e-05 - val_loss: 0.0014
# Epoch 7793/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6898e-05 - val_loss: 0.0013
# Epoch 7794/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.2702e-05 - val_loss: 0.0012
# Epoch 7795/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0903e-05 - val_loss: 0.0011
# Epoch 7796/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.2164e-05 - val_loss: 0.0011
# Epoch 7797/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.4127e-05 - val_loss: 0.0012
# Epoch 7798/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5040e-05 - val_loss: 0.0013
# Epoch 7799/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5074e-05 - val_loss: 0.0013
# Epoch 7800/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.4703e-05 - val_loss: 0.0014
# Epoch 7801/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5251e-05 - val_loss: 0.0014
# Epoch 7802/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6193e-05 - val_loss: 0.0014
# Epoch 7803/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6477e-05 - val_loss: 0.0014
# Epoch 7804/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5901e-05 - val_loss: 0.0014
# Epoch 7805/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6946e-05 - val_loss: 0.0014
# Epoch 7806/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8620e-05 - val_loss: 0.0013
# Epoch 7807/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0316e-05 - val_loss: 0.0013
# Epoch 7808/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2285e-05 - val_loss: 0.0012
# Epoch 7809/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.2355e-05 - val_loss: 0.0012
# Epoch 7810/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0595e-05 - val_loss: 0.0012
# Epoch 7811/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8209e-05 - val_loss: 0.0011
# Epoch 7812/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8860e-05 - val_loss: 0.0011
# Epoch 7813/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0812e-05 - val_loss: 0.0011
# Epoch 7814/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1167e-05 - val_loss: 0.0012
# Epoch 7815/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.3598e-05 - val_loss: 0.0012
# Epoch 7816/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.4007e-05 - val_loss: 0.0012
# Epoch 7817/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1998e-05 - val_loss: 0.0012
# Epoch 7818/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.4765e-05 - val_loss: 0.0011
# Epoch 7819/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.6361e-05 - val_loss: 0.0011
# Epoch 7820/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.8479e-05 - val_loss: 0.0011
# Epoch 7821/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.2358e-05 - val_loss: 0.0012
# Epoch 7822/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.3877e-05 - val_loss: 0.0012
# Epoch 7823/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.2794e-05 - val_loss: 0.0012
# Epoch 7824/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.5485e-05 - val_loss: 0.0011
# Epoch 7825/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.7256e-05 - val_loss: 0.0012
# Epoch 7826/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.8157e-05 - val_loss: 0.0014
# Epoch 7827/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.7711e-05 - val_loss: 0.0015
# Epoch 7828/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.3114e-05 - val_loss: 0.0015
# Epoch 7829/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.5247e-05 - val_loss: 0.0015
# Epoch 7830/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.0085e-05 - val_loss: 0.0015
# Epoch 7831/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.8226e-05 - val_loss: 0.0015
# Epoch 7832/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.0368e-05 - val_loss: 0.0015
# Epoch 7833/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.5687e-05 - val_loss: 0.0014
# Epoch 7834/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5877e-05 - val_loss: 0.0013
# Epoch 7835/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9314e-05 - val_loss: 0.0012
# Epoch 7836/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.7374e-05 - val_loss: 0.0012
# Epoch 7837/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7543e-05 - val_loss: 0.0012
# Epoch 7838/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.7152e-05 - val_loss: 0.0013
# Epoch 7839/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.3859e-05 - val_loss: 0.0015
# Epoch 7840/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.3332e-05 - val_loss: 0.0015
# Epoch 7841/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.6946e-05 - val_loss: 0.0016
# Epoch 7842/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.6655e-05 - val_loss: 0.0018
# Epoch 7843/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.7181e-05 - val_loss: 0.0018
# Epoch 7844/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.7264e-05 - val_loss: 0.0019
# Epoch 7845/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.1260e-05 - val_loss: 0.0016
# Epoch 7846/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.9331e-05 - val_loss: 0.0013
# Epoch 7847/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.1255e-05 - val_loss: 0.0013
# Epoch 7848/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.4333e-05 - val_loss: 0.0013
# Epoch 7849/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3245e-05 - val_loss: 0.0014
# Epoch 7850/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9716e-05 - val_loss: 0.0014
# Epoch 7851/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6043e-05 - val_loss: 0.0014
# Epoch 7852/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7946e-05 - val_loss: 0.0013
# Epoch 7853/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2159e-05 - val_loss: 0.0012
# Epoch 7854/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3178e-05 - val_loss: 0.0012
# Epoch 7855/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.3092e-05 - val_loss: 0.0012
# Epoch 7856/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.3574e-05 - val_loss: 0.0012
# Epoch 7857/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1444e-05 - val_loss: 0.0011
# Epoch 7858/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9321e-05 - val_loss: 0.0011
# Epoch 7859/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2476e-05 - val_loss: 0.0012
# Epoch 7860/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.3660e-05 - val_loss: 0.0013
# Epoch 7861/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.9263e-05 - val_loss: 0.0013
# Epoch 7862/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7080e-05 - val_loss: 0.0013
# Epoch 7863/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5156e-05 - val_loss: 0.0013
# Epoch 7864/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.1522e-05 - val_loss: 0.0012
# Epoch 7865/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.7708e-06 - val_loss: 0.0012
# Epoch 7866/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.6055e-06 - val_loss: 0.0012
# Epoch 7867/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.5800e-06 - val_loss: 0.0012
# Epoch 7868/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.8293e-06 - val_loss: 0.0012
# Epoch 7869/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.3632e-06 - val_loss: 0.0013
# Epoch 7870/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.5565e-06 - val_loss: 0.0013
# Epoch 7871/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.4462e-06 - val_loss: 0.0013
# Epoch 7872/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.4494e-06 - val_loss: 0.0012
# Epoch 7873/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.0526e-06 - val_loss: 0.0012
# Epoch 7874/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.0832e-06 - val_loss: 0.0012
# Epoch 7875/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.5975e-06 - val_loss: 0.0012
# Epoch 7876/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.8320e-06 - val_loss: 0.0012
# Epoch 7877/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.6762e-06 - val_loss: 0.0012
# Epoch 7878/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.5944e-06 - val_loss: 0.0012
# Epoch 7879/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.6866e-06 - val_loss: 0.0012
# Epoch 7880/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.1089e-06 - val_loss: 0.0013
# Epoch 7881/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.5971e-06 - val_loss: 0.0013
# Epoch 7882/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.9710e-06 - val_loss: 0.0014
# Epoch 7883/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0175e-05 - val_loss: 0.0014
# Epoch 7884/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0426e-05 - val_loss: 0.0014
# Epoch 7885/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0770e-05 - val_loss: 0.0015
# Epoch 7886/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1604e-05 - val_loss: 0.0015
# Epoch 7887/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.2294e-05 - val_loss: 0.0014
# Epoch 7888/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.3292e-05 - val_loss: 0.0014
# Epoch 7889/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.4375e-05 - val_loss: 0.0014
# Epoch 7890/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4782e-05 - val_loss: 0.0013
# Epoch 7891/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.4939e-05 - val_loss: 0.0012
# Epoch 7892/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5185e-05 - val_loss: 0.0012
# Epoch 7893/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.4969e-05 - val_loss: 0.0012
# Epoch 7894/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.4828e-05 - val_loss: 0.0013
# Epoch 7895/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5581e-05 - val_loss: 0.0013
# Epoch 7896/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4773e-05 - val_loss: 0.0013
# Epoch 7897/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.2813e-05 - val_loss: 0.0013
# Epoch 7898/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0996e-05 - val_loss: 0.0013
# Epoch 7899/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0091e-05 - val_loss: 0.0013
# Epoch 7900/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.0458e-05 - val_loss: 0.0013
# Epoch 7901/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.1416e-05 - val_loss: 0.0013
# Epoch 7902/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.1822e-05 - val_loss: 0.0013
# Epoch 7903/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.2156e-05 - val_loss: 0.0013
# Epoch 7904/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.3380e-05 - val_loss: 0.0013
# Epoch 7905/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.4266e-05 - val_loss: 0.0013
# Epoch 7906/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.3734e-05 - val_loss: 0.0013
# Epoch 7907/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2263e-05 - val_loss: 0.0012
# Epoch 7908/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.1467e-05 - val_loss: 0.0012
# Epoch 7909/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1652e-05 - val_loss: 0.0012
# Epoch 7910/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2575e-05 - val_loss: 0.0011
# Epoch 7911/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.4395e-05 - val_loss: 0.0012
# Epoch 7912/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6471e-05 - val_loss: 0.0012
# Epoch 7913/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8595e-05 - val_loss: 0.0013
# Epoch 7914/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2774e-05 - val_loss: 0.0012
# Epoch 7915/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7834e-05 - val_loss: 0.0012
# Epoch 7916/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.1166e-05 - val_loss: 0.0013
# Epoch 7917/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.1791e-05 - val_loss: 0.0015
# Epoch 7918/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.6533e-05 - val_loss: 0.0016
# Epoch 7919/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.6114e-05 - val_loss: 0.0014
# Epoch 7920/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.5402e-05 - val_loss: 0.0013
# Epoch 7921/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.8403e-05 - val_loss: 0.0011
# Epoch 7922/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.0044e-05 - val_loss: 0.0012
# Epoch 7923/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.6402e-05 - val_loss: 0.0013
# Epoch 7924/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.0640e-05 - val_loss: 0.0013
# Epoch 7925/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1579e-05 - val_loss: 0.0013
# Epoch 7926/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0794e-05 - val_loss: 0.0015
# Epoch 7927/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1441e-05 - val_loss: 0.0014
# Epoch 7928/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.0952e-05 - val_loss: 0.0014
# Epoch 7929/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0774e-05 - val_loss: 0.0013
# Epoch 7930/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0736e-05 - val_loss: 0.0013
# Epoch 7931/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2731e-05 - val_loss: 0.0014
# Epoch 7932/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.3755e-05 - val_loss: 0.0015
# Epoch 7933/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5490e-05 - val_loss: 0.0015
# Epoch 7934/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6101e-05 - val_loss: 0.0014
# Epoch 7935/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2040e-05 - val_loss: 0.0012
# Epoch 7936/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9096e-05 - val_loss: 0.0011
# Epoch 7937/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2403e-05 - val_loss: 0.0011
# Epoch 7938/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.3492e-05 - val_loss: 0.0012
# Epoch 7939/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4306e-05 - val_loss: 0.0012
# Epoch 7940/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.4284e-05 - val_loss: 0.0013
# Epoch 7941/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7134e-05 - val_loss: 0.0013
# Epoch 7942/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.1296e-05 - val_loss: 0.0013
# Epoch 7943/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.3092e-05 - val_loss: 0.0012
# Epoch 7944/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.3783e-05 - val_loss: 0.0013
# Epoch 7945/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.2870e-05 - val_loss: 0.0013
# Epoch 7946/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.4253e-05 - val_loss: 0.0012
# Epoch 7947/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7170e-05 - val_loss: 0.0010
# Epoch 7948/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.7358e-05 - val_loss: 9.8127e-04
# Epoch 7949/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.3465e-05 - val_loss: 9.5411e-04
# Epoch 7950/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8676e-05 - val_loss: 0.0011
# Epoch 7951/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4222e-05 - val_loss: 0.0012
# Epoch 7952/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2250e-05 - val_loss: 0.0012
# Epoch 7953/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2963e-05 - val_loss: 0.0012
# Epoch 7954/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3600e-05 - val_loss: 0.0011
# Epoch 7955/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.7427e-05 - val_loss: 0.0011
# Epoch 7956/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.0880e-05 - val_loss: 0.0011
# Epoch 7957/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2608e-05 - val_loss: 0.0011
# Epoch 7958/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4965e-05 - val_loss: 0.0012
# Epoch 7959/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.4177e-05 - val_loss: 0.0012
# Epoch 7960/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6522e-05 - val_loss: 0.0012
# Epoch 7961/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.7172e-05 - val_loss: 0.0011
# Epoch 7962/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4225e-05 - val_loss: 0.0011
# Epoch 7963/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.7199e-05 - val_loss: 0.0012
# Epoch 7964/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.6391e-05 - val_loss: 0.0011
# Epoch 7965/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4312e-05 - val_loss: 0.0012
# Epoch 7966/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4873e-05 - val_loss: 0.0012
# Epoch 7967/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.2407e-05 - val_loss: 0.0012
# Epoch 7968/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.6716e-05 - val_loss: 0.0014
# Epoch 7969/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.1851e-05 - val_loss: 0.0014
# Epoch 7970/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.3436e-05 - val_loss: 0.0016
# Epoch 7971/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.7225e-05 - val_loss: 0.0015
# Epoch 7972/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.5052e-05 - val_loss: 0.0016
# Epoch 7973/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7192e-05 - val_loss: 0.0014
# Epoch 7974/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0420e-05 - val_loss: 0.0012
# Epoch 7975/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.1640e-05 - val_loss: 0.0012
# Epoch 7976/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.2453e-05 - val_loss: 0.0013
# Epoch 7977/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0207e-05 - val_loss: 0.0013
# Epoch 7978/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8974e-05 - val_loss: 0.0013
# Epoch 7979/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7147e-05 - val_loss: 0.0012
# Epoch 7980/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8258e-05 - val_loss: 0.0012
# Epoch 7981/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0746e-05 - val_loss: 0.0013
# Epoch 7982/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9990e-05 - val_loss: 0.0013
# Epoch 7983/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6988e-05 - val_loss: 0.0012
# Epoch 7984/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5062e-05 - val_loss: 0.0012
# Epoch 7985/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5001e-05 - val_loss: 0.0012
# Epoch 7986/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6907e-05 - val_loss: 0.0012
# Epoch 7987/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.9505e-05 - val_loss: 0.0013
# Epoch 7988/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1549e-05 - val_loss: 0.0013
# Epoch 7989/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.2727e-05 - val_loss: 0.0013
# Epoch 7990/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.3137e-05 - val_loss: 0.0013
# Epoch 7991/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.2228e-05 - val_loss: 0.0013
# Epoch 7992/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.0866e-05 - val_loss: 0.0014
# Epoch 7993/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.9879e-05 - val_loss: 0.0014
# Epoch 7994/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8670e-05 - val_loss: 0.0015
# Epoch 7995/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0820e-05 - val_loss: 0.0014
# Epoch 7996/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.2744e-05 - val_loss: 0.0014
# Epoch 7997/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9924e-05 - val_loss: 0.0013
# Epoch 7998/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7879e-05 - val_loss: 0.0013
# Epoch 7999/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8127e-05 - val_loss: 0.0012
# Epoch 8000/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.8627e-05 - val_loss: 0.0013
# Epoch 8001/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0662e-05 - val_loss: 0.0013
# Epoch 8002/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.3951e-05 - val_loss: 0.0014
# Epoch 8003/10000
# ...
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5428e-05 - val_loss: 0.0018
# Epoch 9926/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.0811e-05 - val_loss: 0.0017
# Epoch 9927/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.4427e-05 - val_loss: 0.0016
# Epoch 9928/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.8910e-05 - val_loss: 0.0017
# Epoch 9929/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.3794e-05 - val_loss: 0.0017
# Epoch 9930/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1019e-05 - val_loss: 0.0016
# Epoch 9931/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.2460e-05 - val_loss: 0.0015
# Epoch 9932/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0537e-05 - val_loss: 0.0015
# Epoch 9933/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2863e-05 - val_loss: 0.0015
# Epoch 9934/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.8344e-05 - val_loss: 0.0015
# Epoch 9935/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.5688e-05 - val_loss: 0.0015
# Epoch 9936/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.4840e-05 - val_loss: 0.0016
# Epoch 9937/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8531e-05 - val_loss: 0.0017
# Epoch 9938/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.8752e-05 - val_loss: 0.0018
# Epoch 9939/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5295e-05 - val_loss: 0.0018
# Epoch 9940/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.1862e-05 - val_loss: 0.0016
# Epoch 9941/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1043e-05 - val_loss: 0.0016
# Epoch 9942/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3972e-05 - val_loss: 0.0016
# Epoch 9943/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6942e-05 - val_loss: 0.0016
# Epoch 9944/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.5375e-05 - val_loss: 0.0017
# Epoch 9945/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.6608e-05 - val_loss: 0.0018
# Epoch 9946/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.6108e-05 - val_loss: 0.0018
# Epoch 9947/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.7425e-05 - val_loss: 0.0018
# Epoch 9948/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.4362e-05 - val_loss: 0.0018
# Epoch 9949/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.6232e-05 - val_loss: 0.0017
# Epoch 9950/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.4867e-05 - val_loss: 0.0016
# Epoch 9951/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.5583e-05 - val_loss: 0.0016
# Epoch 9952/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.8611e-05 - val_loss: 0.0014
# Epoch 9953/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.1292e-05 - val_loss: 0.0015
# Epoch 9954/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.2155e-05 - val_loss: 0.0016
# Epoch 9955/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.3286e-05 - val_loss: 0.0016
# Epoch 9956/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.2440e-05 - val_loss: 0.0016
# Epoch 9957/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.9193e-05 - val_loss: 0.0015
# Epoch 9958/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.2022e-05 - val_loss: 0.0015
# Epoch 9959/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.5343e-05 - val_loss: 0.0015
# Epoch 9960/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.2214e-05 - val_loss: 0.0015
# Epoch 9961/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.4546e-05 - val_loss: 0.0016
# Epoch 9962/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.4306e-05 - val_loss: 0.0017
# Epoch 9963/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.5899e-05 - val_loss: 0.0016
# Epoch 9964/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.4697e-05 - val_loss: 0.0017
# Epoch 9965/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.3751e-05 - val_loss: 0.0017
# Epoch 9966/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.2642e-05 - val_loss: 0.0019
# Epoch 9967/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.5164e-05 - val_loss: 0.0018
# Epoch 9968/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8650e-05 - val_loss: 0.0017
# Epoch 9969/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.2825e-05 - val_loss: 0.0018
# Epoch 9970/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.2019e-05 - val_loss: 0.0018
# Epoch 9971/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.4587e-05 - val_loss: 0.0020
# Epoch 9972/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.5758e-05 - val_loss: 0.0018
# Epoch 9973/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.3292e-05 - val_loss: 0.0016
# Epoch 9974/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.0179e-05 - val_loss: 0.0016
# Epoch 9975/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.0229e-05 - val_loss: 0.0017
# Epoch 9976/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.0080e-05 - val_loss: 0.0015
# Epoch 9977/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.8405e-05 - val_loss: 0.0016
# Epoch 9978/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0854e-04 - val_loss: 0.0014
# Epoch 9979/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.4553e-05 - val_loss: 0.0013
# Epoch 9980/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.2577e-05 - val_loss: 0.0013
# Epoch 9981/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.8182e-05 - val_loss: 0.0014
# Epoch 9982/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.3971e-05 - val_loss: 0.0013
# Epoch 9983/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.8557e-05 - val_loss: 0.0014
# Epoch 9984/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.0735e-05 - val_loss: 0.0014
# Epoch 9985/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.4909e-05 - val_loss: 0.0014
# Epoch 9986/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.6643e-05 - val_loss: 0.0014
# Epoch 9987/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.7608e-05 - val_loss: 0.0015
# Epoch 9988/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.5698e-05 - val_loss: 0.0013
# Epoch 9989/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.4942e-05 - val_loss: 0.0013
# Epoch 9990/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.0207e-05 - val_loss: 0.0015
# Epoch 9991/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.3971e-05 - val_loss: 0.0013
# Epoch 9992/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.4961e-05 - val_loss: 0.0011
# Epoch 9993/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.8462e-05 - val_loss: 0.0013
# Epoch 9994/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.3967e-05 - val_loss: 0.0012
# Epoch 9995/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.4264e-05 - val_loss: 0.0012
# Epoch 9996/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.2862e-05 - val_loss: 0.0011
# Epoch 9997/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.9228e-05 - val_loss: 0.0011
# Epoch 9998/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.8732e-05 - val_loss: 0.0011
# Epoch 9999/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.3212e-05 - val_loss: 9.2701e-04
# Epoch 10000/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.1516e-05 - val_loss: 9.8213e-04
# --- Starting Reinforcement Learning Fine-Tuning (Batched) ---
# RL Epoch 1/150, Average Loss per Batch: 0.000071
# RL Epoch 2/150, Average Loss per Batch: 0.000039
# RL Epoch 3/150, Average Loss per Batch: 0.000029
# RL Epoch 4/150, Average Loss per Batch: 0.000026
# RL Epoch 5/150, Average Loss per Batch: 0.000025
# RL Epoch 6/150, Average Loss per Batch: 0.000023
# RL Epoch 7/150, Average Loss per Batch: 0.000022
# RL Epoch 8/150, Average Loss per Batch: 0.000020
# RL Epoch 9/150, Average Loss per Batch: 0.000019
# RL Epoch 10/150, Average Loss per Batch: 0.000018
# RL Epoch 11/150, Average Loss per Batch: 0.000018
# RL Epoch 12/150, Average Loss per Batch: 0.000017
# RL Epoch 13/150, Average Loss per Batch: 0.000016
# RL Epoch 14/150, Average Loss per Batch: 0.000015
# RL Epoch 15/150, Average Loss per Batch: 0.000015
# RL Epoch 16/150, Average Loss per Batch: 0.000014
# RL Epoch 17/150, Average Loss per Batch: 0.000014
# RL Epoch 18/150, Average Loss per Batch: 0.000014
# RL Epoch 19/150, Average Loss per Batch: 0.000013
# RL Epoch 20/150, Average Loss per Batch: 0.000013
# RL Epoch 21/150, Average Loss per Batch: 0.000012
# RL Epoch 22/150, Average Loss per Batch: 0.000012
# RL Epoch 23/150, Average Loss per Batch: 0.000012
# RL Epoch 24/150, Average Loss per Batch: 0.000011
# RL Epoch 25/150, Average Loss per Batch: 0.000011
# RL Epoch 26/150, Average Loss per Batch: 0.000011
# RL Epoch 27/150, Average Loss per Batch: 0.000011
# RL Epoch 28/150, Average Loss per Batch: 0.000010
# RL Epoch 29/150, Average Loss per Batch: 0.000010
# RL Epoch 30/150, Average Loss per Batch: 0.000010
# RL Epoch 31/150, Average Loss per Batch: 0.000010
# RL Epoch 32/150, Average Loss per Batch: 0.000009
# RL Epoch 33/150, Average Loss per Batch: 0.000009
# RL Epoch 34/150, Average Loss per Batch: 0.000009
# RL Epoch 35/150, Average Loss per Batch: 0.000009
# RL Epoch 36/150, Average Loss per Batch: 0.000009
# RL Epoch 37/150, Average Loss per Batch: 0.000009
# RL Epoch 38/150, Average Loss per Batch: 0.000008
# RL Epoch 39/150, Average Loss per Batch: 0.000008
# RL Epoch 40/150, Average Loss per Batch: 0.000008
# RL Epoch 41/150, Average Loss per Batch: 0.000008
# RL Epoch 42/150, Average Loss per Batch: 0.000008
# RL Epoch 43/150, Average Loss per Batch: 0.000008
# RL Epoch 44/150, Average Loss per Batch: 0.000007
# RL Epoch 45/150, Average Loss per Batch: 0.000007
# RL Epoch 46/150, Average Loss per Batch: 0.000007
# RL Epoch 47/150, Average Loss per Batch: 0.000007
# RL Epoch 48/150, Average Loss per Batch: 0.000007
# RL Epoch 49/150, Average Loss per Batch: 0.000010
# RL Epoch 50/150, Average Loss per Batch: 0.000017
# RL Epoch 51/150, Average Loss per Batch: 0.000053
# RL Epoch 52/150, Average Loss per Batch: 0.000061
# RL Epoch 53/150, Average Loss per Batch: 0.000044
# RL Epoch 54/150, Average Loss per Batch: 0.000016
# RL Epoch 55/150, Average Loss per Batch: 0.000012
# RL Epoch 56/150, Average Loss per Batch: 0.000012
# RL Epoch 57/150, Average Loss per Batch: 0.000009
# RL Epoch 58/150, Average Loss per Batch: 0.000010
# RL Epoch 59/150, Average Loss per Batch: 0.000010
# RL Epoch 60/150, Average Loss per Batch: 0.000009
# RL Epoch 61/150, Average Loss per Batch: 0.000010
# RL Epoch 62/150, Average Loss per Batch: 0.000010
# RL Epoch 63/150, Average Loss per Batch: 0.000010
# RL Epoch 64/150, Average Loss per Batch: 0.000010
# RL Epoch 65/150, Average Loss per Batch: 0.000010
# RL Epoch 66/150, Average Loss per Batch: 0.000010
# RL Epoch 67/150, Average Loss per Batch: 0.000010
# RL Epoch 68/150, Average Loss per Batch: 0.000010
# RL Epoch 69/150, Average Loss per Batch: 0.000010
# RL Epoch 70/150, Average Loss per Batch: 0.000010
# RL Epoch 71/150, Average Loss per Batch: 0.000009
# RL Epoch 72/150, Average Loss per Batch: 0.000009
# RL Epoch 73/150, Average Loss per Batch: 0.000009
# RL Epoch 74/150, Average Loss per Batch: 0.000009
# RL Epoch 75/150, Average Loss per Batch: 0.000009
# RL Epoch 76/150, Average Loss per Batch: 0.000009
# RL Epoch 77/150, Average Loss per Batch: 0.000009
# RL Epoch 78/150, Average Loss per Batch: 0.000009
# RL Epoch 79/150, Average Loss per Batch: 0.000009
# RL Epoch 80/150, Average Loss per Batch: 0.000009
# RL Epoch 81/150, Average Loss per Batch: 0.000009
# RL Epoch 82/150, Average Loss per Batch: 0.000009
# RL Epoch 83/150, Average Loss per Batch: 0.000009
# RL Epoch 84/150, Average Loss per Batch: 0.000009
# RL Epoch 85/150, Average Loss per Batch: 0.000009
# RL Epoch 86/150, Average Loss per Batch: 0.000009
# RL Epoch 87/150, Average Loss per Batch: 0.000009
# RL Epoch 88/150, Average Loss per Batch: 0.000009
# RL Epoch 89/150, Average Loss per Batch: 0.000009
# RL Epoch 90/150, Average Loss per Batch: 0.000009
# RL Epoch 91/150, Average Loss per Batch: 0.000009
# RL Epoch 92/150, Average Loss per Batch: 0.000009
# RL Epoch 93/150, Average Loss per Batch: 0.000009
# RL Epoch 94/150, Average Loss per Batch: 0.000009
# RL Epoch 95/150, Average Loss per Batch: 0.000009
# RL Epoch 96/150, Average Loss per Batch: 0.000009
# RL Epoch 97/150, Average Loss per Batch: 0.000009
# RL Epoch 98/150, Average Loss per Batch: 0.000009
# RL Epoch 99/150, Average Loss per Batch: 0.000009
# RL Epoch 100/150, Average Loss per Batch: 0.000009
# RL Epoch 101/150, Average Loss per Batch: 0.000009
# RL Epoch 102/150, Average Loss per Batch: 0.000009
# RL Epoch 103/150, Average Loss per Batch: 0.000009
# RL Epoch 104/150, Average Loss per Batch: 0.000009
# RL Epoch 105/150, Average Loss per Batch: 0.000009
# RL Epoch 106/150, Average Loss per Batch: 0.000009
# RL Epoch 107/150, Average Loss per Batch: 0.000009
# RL Epoch 108/150, Average Loss per Batch: 0.000009
# RL Epoch 109/150, Average Loss per Batch: 0.000009
# RL Epoch 110/150, Average Loss per Batch: 0.000009
# RL Epoch 111/150, Average Loss per Batch: 0.000009
# RL Epoch 112/150, Average Loss per Batch: 0.000009
# RL Epoch 113/150, Average Loss per Batch: 0.000008
# RL Epoch 114/150, Average Loss per Batch: 0.000008
# RL Epoch 115/150, Average Loss per Batch: 0.000008
# RL Epoch 116/150, Average Loss per Batch: 0.000008
# RL Epoch 117/150, Average Loss per Batch: 0.000008
# RL Epoch 118/150, Average Loss per Batch: 0.000008
# RL Epoch 119/150, Average Loss per Batch: 0.000008
# RL Epoch 120/150, Average Loss per Batch: 0.000008
# RL Epoch 121/150, Average Loss per Batch: 0.000008
# RL Epoch 122/150, Average Loss per Batch: 0.000008
# RL Epoch 123/150, Average Loss per Batch: 0.000008
# RL Epoch 124/150, Average Loss per Batch: 0.000008
# RL Epoch 125/150, Average Loss per Batch: 0.000008
# RL Epoch 126/150, Average Loss per Batch: 0.000008
# RL Epoch 127/150, Average Loss per Batch: 0.000008
# RL Epoch 128/150, Average Loss per Batch: 0.000008
# RL Epoch 129/150, Average Loss per Batch: 0.000008
# RL Epoch 130/150, Average Loss per Batch: 0.000008
# RL Epoch 131/150, Average Loss per Batch: 0.000008
# RL Epoch 132/150, Average Loss per Batch: 0.000008
# RL Epoch 133/150, Average Loss per Batch: 0.000008
# RL Epoch 134/150, Average Loss per Batch: 0.000008
# RL Epoch 135/150, Average Loss per Batch: 0.000008
# RL Epoch 136/150, Average Loss per Batch: 0.000008
# RL Epoch 137/150, Average Loss per Batch: 0.000008
# RL Epoch 138/150, Average Loss per Batch: 0.000008
# RL Epoch 139/150, Average Loss per Batch: 0.000008
# RL Epoch 140/150, Average Loss per Batch: 0.000008
# RL Epoch 141/150, Average Loss per Batch: 0.000008
# RL Epoch 142/150, Average Loss per Batch: 0.000008
# RL Epoch 143/150, Average Loss per Batch: 0.000007
# RL Epoch 144/150, Average Loss per Batch: 0.000007
# RL Epoch 145/150, Average Loss per Batch: 0.000007
# RL Epoch 146/150, Average Loss per Batch: 0.000007
# RL Epoch 147/150, Average Loss per Batch: 0.000007
# RL Epoch 148/150, Average Loss per Batch: 0.000007
# RL Epoch 149/150, Average Loss per Batch: 0.000007
# RL Epoch 150/150, Average Loss per Batch: 0.000007
# --- RL Fine-Tuning Complete ---
#
#  Training Set Performance Metrics (RNN):
#  Mean Absolute Error (MAE) : ₹3.28
#  Mean Squared Error (MSE)  : ₹16.53
#  Root Squared Error (RMSE) : ₹4.07
#  R² Score                  : 0.9996
#  Mean Absolute Percentage Error (MAPE) : 0.23%
#  Accuracy (100 - MAPE) : 99.77%
#  MSE Percentage of Average Price : 1.19%
#  MAE Percentage of Average Price : 0.24%
#
#  Validation Set Performance Metrics (RNN):
#  Mean Absolute Error (MAE) : ₹41.67
#  Mean Squared Error (MSE)  : ₹2464.14
#  Root Squared Error (RMSE) : ₹49.64
#  R² Score                  : 0.9016
#  Mean Absolute Percentage Error (MAPE) : 2.38%
#  Accuracy (100 - MAPE) : 97.62%
#  MSE Percentage of Average Price: 141.52%
#  MAE Percentage of Average Price: 2.39%
#
#  Prediction for 2025-06-18:
#  Predicted Closing Price: ₹1642.42
#  Actual Closing Price   : ₹1632.9000244140625
#  Test Set Performance Metrics (RNN):
#  Mean Absolute Error (MAE) : ₹26.90
#  Mean Squared Error (MSE)  : ₹1097.34
#  Root Squared Error (RMSE) : ₹33.13
#  R² Score                  : -0.2870
#  Mean Absolute Percentage Error (MAPE) : 1.68%
#  Accuracy (100 - MAPE) : 98.32%
#  MSE Percentage of Average Price: 68.75%
#  MAE Percentage of Average Price: 1.68%

# %% [markdown]
# # **200 episodes**

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import SimpleRNN
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
from matplotlib.dates import DateFormatter
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
import numpy as np
import pandas as pd
import datetime
import holidays
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import warnings

warnings.filterwarnings('ignore')

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

SYMBOL = "INFY.NS"
SEQUENCE_LENGTH = 60

TRAIN_START_DATE = "2020-06-01"
TRAIN_END_DATE = "2025-05-31"

TEST_START_DATE = "2025-06-01"
TEST_END_DATE = "2025-07-01"

# Get Indian trading holidays
def get_nse_holidays():
    in_holidays = holidays.India(years=range(2020, 2026))
    return set(in_holidays.keys())

TRADING_HOLIDAYS = get_nse_holidays()

def is_valid_date(date_str):
    try:
        date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()
        if not (datetime.date(2025, 6, 1) <= date <= datetime.date(2025, 7, 1)):
            print("Date must be between 2025-06-01 and 2025-07-01.")
            return False
        if date.weekday() >= 5:
            print("Weekends are not trading days.")
            return False
        if date in TRADING_HOLIDAYS:
            print("Entered date is a trading holiday.")
            return False
        return True
    except ValueError:
        print("Invalid date format. Use YYYY-MM-DD.")
        return False

def get_stock_data():
    print("Fetching data from Yahoo Finance...")
    full_df = yf.download(SYMBOL, start=TRAIN_START_DATE, end=TEST_END_DATE)
    full_df = full_df[['Close']]
    full_df.dropna(inplace=True)
    full_df.index = pd.to_datetime(full_df.index)

    train_df = full_df.loc[TRAIN_START_DATE:TRAIN_END_DATE]
    test_df = full_df.loc[TEST_START_DATE:TEST_END_DATE]
    return train_df, test_df, full_df

# Prompt until valid date is entered
def get_user_date():
    while True:
        date_input = input("Enter a date (YYYY-MM-DD): ")
        if is_valid_date(date_input):
            return datetime.datetime.strptime(date_input, "%Y-%m-%d").date()

# Build the SimpleRNN model
def build_model(input_shape, learning_rate=0.001): # Added learning_rate parameter
    model = Sequential()
    model.add(SimpleRNN(units=50, activation='tanh', input_shape=input_shape))
    model.add(Dense(1))
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate) # Use custom learning rate
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# Reinforcement Learning Fine-Tuning
class RLAgent:
    """
    A simple RL Agent to fine-tune the RNN model.
    The "environment" is the time series data, and the "action" is the prediction.
    The reward is based on prediction accuracy.
    """
    def __init__(self, model, learning_rate=0.001):
        self.model = model
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate) # Pass learning_rate to RLAgent

    @tf.function
    def train_step(self, state, target):
        """
        Performs a single training step to fine-tune the model weights.
        """
        with tf.GradientTape() as tape:
            prediction = self.model(state, training=True)
            # Use Mean Squared Error directly as the loss to minimize
            loss = tf.reduce_mean(tf.square(tf.cast(target, tf.float32) - prediction))

        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))
        return loss # Return the mean loss for the batch


def fine_tune_with_rl(model, X_train, y_train, epochs=5, learning_rate=0.001, batch_size=32):
    """
    Fine- tunes the pre-trained RNN model using a simple reinforcement learning loop with batched data.
    """
    print("\n--- Starting Reinforcement Learning Fine-Tuning (Batched) ---")
    agent = RLAgent(model, learning_rate=learning_rate)

    # Create a TensorFlow Dataset and batch it
    dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
    dataset = dataset.batch(batch_size)

    num_batches = tf.data.experimental.cardinality(dataset).numpy()

    for epoch in range(epochs):
        total_loss = 0
        batch_count = 0
        for batch_x, batch_y in dataset:
            # Ensure batch_x has the correct shape (batch_size, sequence_length, 1)
            batch_x_reshaped = tf.reshape(batch_x, (tf.shape(batch_x)[0], tf.shape(batch_x)[1], 1))
            loss = agent.train_step(batch_x_reshaped, batch_y)
            total_loss += loss.numpy() # Sum up the mean loss for each batch
            batch_count += 1

        # Calculate average loss per epoch
        average_epoch_loss = total_loss / num_batches if num_batches > 0 else 0
        print(f"RL Epoch {epoch + 1}/{epochs}, Average Loss per Batch: {average_epoch_loss:.6f}") # Print average loss

    print("--- RL Fine-Tuning Complete ---")
    return model


def create_test_sequences(train_df, test_df, scaler):
    combined = pd.concat([train_df, test_df])
    scaled = scaler.transform(combined[['Close']])
    X_test = []
    test_dates = test_df.index.date

    for i in range(len(train_df), len(combined)):
        if i - SEQUENCE_LENGTH < 0:
            continue
        seq = scaled[i - SEQUENCE_LENGTH:i]
        X_test.append(seq)

    X_test = np.array(X_test)
    return X_test, test_dates

def predict_price_on_test(model, full_df, scaler, user_date):
    all_dates = full_df.index.date
    try:
        idx = list(all_dates).index(user_date)
    except ValueError:
        print("User date not found in data.")
        return None, None, user_date

    if idx < SEQUENCE_LENGTH:
        print("Not enough data to predict for this date.")
        return None, None, user_date

    input_seq = scaler.transform(full_df[['Close']].values)[idx - SEQUENCE_LENGTH:idx]
    input_seq = np.reshape(input_seq, (1, SEQUENCE_LENGTH, 1))

    predicted_scaled = model.predict(input_seq, verbose=0)
    predicted_price = scaler.inverse_transform(predicted_scaled)[0][0]

    actual_price = float(full_df.iloc[idx]['Close']) if idx < len(full_df) else None
    return predicted_price, actual_price, full_df.index[idx].date()

# Plot the result
def plot_results(df, predicted_date, predicted_price, actual_price):
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['Close'], label='Historical Close Price',zorder=1)
    #plt.axvline(pd.to_datetime(predicted_date), color='red', linestyle='--', label='Predicted Date')
    plt.scatter(pd.to_datetime(predicted_date), predicted_price, color='orange', label='Predicted Price',zorder=2)
    if actual_price is not None:
        plt.scatter(pd.to_datetime(predicted_date), actual_price, color='green', label='Actual Price',zorder=3, s=100)
    plt.title("INFOSYS Stock Price with Prediction (yfinance)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

#Plotting error with no. of epochs
def plot_training_loss(history):
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title("Training and Validation Loss Over Epochs (RNN)")
    plt.xlabel("Epoch no.")
    plt.ylabel("Loss (MSE)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def main():
    print("=== INFOSYS LSTM Stock Price Predictor (Test Phase June–July 2025) ===")
    user_date = get_user_date()

    # Step 1: Get stock data
    train_df, test_df, full_df = get_stock_data()

    # Step 2: Preprocess
    scaler = MinMaxScaler()
    scaled_train = scaler.fit_transform(train_df[['Close']])
    X, y = [], []
    for i in range(SEQUENCE_LENGTH, len(scaled_train)):
        X.append(scaled_train[i - SEQUENCE_LENGTH:i])
        y.append(scaled_train[i])
    X = np.array(X)
    y = np.array(y)

    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)
    #early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
    # Step 3: Build and train model
    model = build_model((X_train.shape[1], 1), learning_rate=0.0005) # Reduced Adam learning rate
    print("Training RNN model...")
    history = model.fit(X_train, y_train, epochs=10000, batch_size=64, validation_data=(X_val, y_val), verbose = 1) #callbacks = [early_stop], verbose=1)

    #print(f"\nBest weights restored from epoch: {early_stop.best_epoch + 1}")

    # Step 4: Plot training loss
    plot_training_loss(history)

    # Step 5: Fine-tune with Reinforcement Learning
    rl_tuned_model = fine_tune_with_rl(model, X_train, y_train, epochs=200, learning_rate=0.0001, batch_size=32)

    # Predict on training data to evaluate performance
    y_train_pred_scaled = rl_tuned_model.predict(X_train, verbose=0)
    y_train_pred = scaler.inverse_transform(y_train_pred_scaled)
    y_true_train = scaler.inverse_transform(y_train.reshape(-1, 1))

    # Calculate and print training metrics
    mae_train = mean_absolute_error(y_true_train, y_train_pred)
    mse_train = mean_squared_error(y_true_train, y_train_pred)
    rmse_train = np.sqrt(mse_train)
    r2_train = r2_score(y_true_train, y_train_pred)
    mape_train = mean_absolute_percentage_error(y_true_train, y_train_pred) * 100
    accuracy_train = 100 - mape_train
    mse_percent_train = (mse_train / np.mean(y_true_train)) * 100 if np.mean(y_true_train) != 0 else np.nan
    mae_percent_train = (mae_train / np.mean(y_true_train)) * 100 if np.mean(y_true_train) != 0 else np.nan
    print("\n Training Set Performance Metrics (RNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_train:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_train:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_train:.2f}")
    print(f" R² Score                  : {r2_train:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_train:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_train:.2f}%")
    print(f" MSE Percentage of Average Price : {mse_percent_train:.2f}%")
    print(f" MAE Percentage of Average Price : {mae_percent_train:.2f}%")

    # Predict on validation set
    y_val_pred_scaled = rl_tuned_model.predict(X_val, verbose=0)
    y_val_pred = scaler.inverse_transform(y_val_pred_scaled)
    y_val_true = scaler.inverse_transform(y_val.reshape(-1, 1))

    # Calculate and print validation metrics
    mae_val = mean_absolute_error(y_val_true, y_val_pred)
    mse_val = mean_squared_error(y_val_true, y_val_pred)
    rmse_val = np.sqrt(mse_val)
    r2_val = r2_score(y_val_true, y_val_pred)
    mape_val = mean_absolute_percentage_error(y_val_true, y_val_pred) * 100
    accuracy_val = 100 - mape_val
    mse_percent_val = (mse_val / np.mean(y_val_true)) * 100 if np.mean(y_val_true) != 0 else np.nan
    mae_percent_val = (mae_val / np.mean(y_val_true)) * 100 if np.mean(y_val_true) != 0 else np.nan
    print("\n Validation Set Performance Metrics (RNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_val:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_val:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_val:.2f}")
    print(f" R² Score                  : {r2_val:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_val:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_val:.2f}%")
    print(f" MSE Percentage of Average Price: {mse_percent_val:.2f}%")
    print(f" MAE Percentage of Average Price: {mae_percent_val:.2f}%")


    # Step 6: Predict for user-input test date
    predicted_price, actual_price, predicted_date = predict_price_on_test(rl_tuned_model, full_df, scaler, user_date)
    if predicted_price is not None:
        print(f"\n Prediction for {predicted_date}:")
        print(f" Predicted Closing Price: ₹{predicted_price:.2f}")
        if actual_price is not None:
            print(f" Actual Closing Price   : ₹{actual_price}")
        else:
            print("Actual price not available.")

        plot_results(full_df, predicted_date, predicted_price, actual_price)
    else:
        print("❌ Unable to make prediction.")

    # === Step 7: Predict all test dates and compare ===

    # Reuse combined full_df
    combined_df = pd.concat([train_df, test_df])
    scaled_combined = scaler.transform(combined_df[['Close']])

    X_test_all = []
    test_date_indexes = []

    for i in range(len(train_df), len(combined_df)):
        if i - SEQUENCE_LENGTH < 0:
            continue
        seq = scaled_combined[i - SEQUENCE_LENGTH:i]
        X_test_all.append(seq)
        test_date_indexes.append(combined_df.index[i])

    X_test_all = np.array(X_test_all)

    # Predict on test sequences
    y_test_pred_scaled = rl_tuned_model.predict(X_test_all, verbose=0)
    y_test_pred = scaler.inverse_transform(y_test_pred_scaled)

    # Actual prices
    y_test_true = test_df.loc[test_date_indexes, 'Close'].values

    # Calculate and print test metrics
    mae_test = mean_absolute_error(y_test_true, y_test_pred)
    mse_test = mean_squared_error(y_test_true, y_test_pred)
    rmse_test = np.sqrt(mse_test)
    r2_test = r2_score(y_test_true, y_test_pred)
    mape_test = mean_absolute_percentage_error(y_test_true, y_test_pred) * 100
    accuracy_test = 100 - mape_test
    mse_percent_test = (mse_test / np.mean(y_test_true)) * 100 if np.mean(y_test_true) != 0 else np.nan
    mae_percent_test = (mae_test / np.mean(y_test_true)) * 100 if np.mean(y_test_true) != 0 else np.nan
    print("\n Test Set Performance Metrics (RNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_test:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_test:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_test:.2f}")
    print(f" R² Score                  : {r2_test:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_test:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_test:.2f}%")
    print(f" MSE Percentage of Average Price: {mse_percent_test:.2f}%")
    print(f" MAE Percentage of Average Price: {mae_percent_test:.2f}%")

    # Plot actual vs predicted
    plt.figure(figsize=(12, 6))
    plt.plot(test_date_indexes, y_test_true, label='Actual Price')
    plt.plot(test_date_indexes, y_test_pred, label='Predicted Price')
    plt.title("Actual vs Predicted INFY Closing Prices (01-Jun to 01-Jul 2025)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.xticks(rotation=45)
    plt.gca().xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()
